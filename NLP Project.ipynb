# %%
from selenium import webdriver
from tqdm import tqdm
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
# INSTANTIATE DRIVER -> REPLACE WITH YOUR WEBBROWSER
driver = webdriver.Edge()
driver.get("https://www.ecb.europa.eu/press/pressconf/html/index.en.html")

# SCROLL THROUGH THE WEBPAGE TO LOAD ALL CONTENT
for x in range(0, 10000, 200):
    driver.execute_script("window.scrollBy(0, " +str(x)+");")
    time.sleep(0.5)

# %%
# GET WEBPAGE SOURCE CONTENT
html = driver.page_source
title = driver.title
soup = BeautifulSoup(html)

# %%
# LOOK FOR ALL LINKS PRESENT IN THE WEBPAGE
r = []
for i in soup.find_all("a", href=True):
    r.append(i["href"])

# REMOVE DUPLICATES
r = list(set(r))

# CONSTRUCT DATAFRAME
df = pd.DataFrame(r, columns=["link"])
df = df.sort_values("link")

# %%
df = df.loc[
   (df['link'].str.contains("press_conference/monetary-policy")) &
   (df['link'].str.contains(".en.html"))
   ]

# %%
content = []
date = []
title = []

print(f"TOTAL DOCUMENTS : {len(df)}")

for i, x in tqdm(df.iterrows(), total=df.shape[0]):

    url = "https://www.ecb.europa.eu" + x["link"]

    try:
        req = requests.get(url)
        soup = BeautifulSoup(req.content, 'html.parser')

        c = []
        sections = soup.find_all("div", {"class":"section"})
        for section in sections:
            for text_container in section.find_all(["h2","p"]):
                c.append(text_container.text.strip())

        content.append("\n".join(c))

        h1_tag = soup.find("h1")
        titre_ajouté = False

        if h1_tag:
            h1_text = h1_tag.text.strip()
            if ("introductory statement" in h1_text.lower()) or ("monetary policy statement" in h1_text.lower()or ("press conference" in h1_text.lower())):
                title.append(h1_text)
                titre_ajouté = True

        if not titre_ajouté:
            title.append(None)

        meta_date = soup.find("meta", {"property":"article:published_time"})
        date_ajoutée = False

        if meta_date:
            date_str = meta_date["content"]
            date.append(date_str)
            date_ajoutée = True

        if not date_ajoutée:
            date.append(None)

    except Exception as e:
        print(f"Erreur sur le lien {url}: {e}")
        content.append("")
        title.append(None)
        date.append(None)

df["content"] = content
df["date"] = date
df["title"] = title

df = df.dropna(subset=["title", "date"])
# Out:
# TOTAL DOCUMENTS : 293
# 100%|██████████| 293/293 [01:09<00:00,  4.21it/s]

# %%
# 1. Convertir la date et extraire l'année
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

# 2. Filtrer pour exclure 1998
df = df[df['year'] != 1998]

# 3. Exclure les liens indésirables
liens_intrus = [
    '/press/press_conference/monetary-policy-statement/2000/html/is000330.en.html',
    '/press/press_conference/monetary-policy-statement/2000/html/is001019.en.html',
    '/press/press_conference/monetary-policy-statement/2001/html/is011213.en.html',
    '/press/press_conference/monetary-policy-statement/2002/html/is020103_2.en.html',
    '/press/press_conference/monetary-policy-statement/2003/html/is030917.en.html',
    '/press/press_conference/monetary-policy-statement/2003/html/is031013.en.html',
    '/press/press_conference/monetary-policy-statement/2005/html/is050120.en.html',
    '/press/press_conference/monetary-policy-statement/2005/html/is050120_1.en.html',
    '/press/press_conference/monetary-policy-statement/2014/html/is141026.en.html',
    '/press/press_conference/monetary-policy-statement/2021/html/ecb.sp210708~ab68c3bd9d.en.html',
    '/press/press_conference/monetary-policy-statement/html/index.en.html'
]

df = df[~df['link'].isin(liens_intrus)]

# %%
# 4. Vérifier le résultat
comptage_par_annee = df['year'].value_counts().sort_index()
print("Nombre de documents par année :")
print(comptage_par_annee)
print(f"\nTotal des documents : {len(df)}")
# Out:
# Nombre de documents par année :
# year
# 1999    11
# 2000    11
# 2001    11
# 2002    11
# 2003    11
# 2004    11
# 2005    11
# 2006    12
# 2007    11
# 2008    12
# 2009    12
# 2010    12
# 2011    12
# 2012    12
# 2013    12
# 2014    12
# 2015     8
# 2016     8
# 2017     8
# 2018     8
# 2019     8
# 2020     8
# 2021     8
# 2022     8
# 2023     8
# 2024     8
# 2025     8
# Name: count, dtype: int64
#
# Total des documents : 272

# %%
stops = stopwords.words("english")
porter = PorterStemmer()

# %%
def clean_text(text):

    text = text.lower()

    markers = [
        "we are now at your disposal",
        "we stand ready to answer any questions you may have",
        "transcript of the questions asked and the answers",
        "question",
        "questions"
    ]

    for marker in markers:
        if marker in text:
            text = text.split(marker)[0]
            break

    if marker in text:
         text = text.split(marker)[0]

    if type(text) != str:
        return np.nan

    text = text.lower()
    text = re.sub(r"[^'a-z\s-]", " ", text)
    tokens = word_tokenize(text)
    tokens = [t for t in tokens if t not in stops]
    tokens = [porter.stem(t) for t in tokens]

    return " ".join(tokens)
df['clean_text'] = df['content'].apply(clean_text)
texts = df['clean_text'].tolist()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

cv = CountVectorizer(
    ngram_range=(2, 2),
    stop_words=None,
    binary=True
)

# 2. Création de la matrice X
# Lignes = Documents, Colonnes = Bigrammes uniques
# C'est une "Sparse Matrix" (matrice creuse) optimisée pour la mémoire
X = cv.fit_transform(df['clean_text'])

# 3. Calcul de la similarité (i vs i-1)
results = [0] # Le premier mois n'a pas d'historique

# On parcourt la matrice ligne par ligne
# (X.shape[0] est le nombre de documents)
for i in range(1, X.shape[0]):

    # On récupère les vecteurs de bigrammes pour le doc actuel et le précédent
    # Ce sont des vecteurs de 0 et de 1
    vec_prev = X[i-1]
    vec_curr = X[i]

    # CALCUL MATHÉMATIQUE DE JACCARD SUR VECTEURS BINAIRES

    # Intersection = Produit scalaire (là où les deux ont "1")
    # multiply() fait une multiplication élément par élément
    intersection = (vec_prev.multiply(vec_curr)).sum()

    # Union = Somme(A) + Somme(B) - Intersection
    # .sum() compte le nombre de "1" (donc le nombre de bigrammes dans le doc)
    n_bigrams_prev = vec_prev.sum()
    n_bigrams_curr = vec_curr.sum()

    union = n_bigrams_prev + n_bigrams_curr - intersection

    # Calcul final
    if union > 0:
        sim = intersection / union
    else:
        sim = 0

    results.append(sim)

# 4. Intégration et Vérification
df['similarity_sklearn'] = results

# Calcul des statistiques pour SIMILARITY
similarity_stats = {
    'Moyenne': df['similarity_sklearn'] .mean(),
    'Écart-type': df['similarity_sklearn'] .std(),
    'Minimum': df['similarity_sklearn'] .min(),
    '1er Quartile': df['similarity_sklearn'] .quantile(0.25),
    'Médiane': df['similarity_sklearn'] .median(),
    '3ème Quartile': df['similarity_sklearn'] .quantile(0.75),
    'Maximum': df['similarity_sklearn'] .max()
}
# Affichage des résultats
print("\n=== STATISTIQUES SIMILARITY ===")
for stat, value in similarity_stats.items():
    print(f"{stat + ':':<15} {value:>10.4f}")
# Out:
# === STATISTIQUES SIMILARITY ===
# Moyenne:            0.2920
# Écart-type:         0.1444
# Minimum:            0.0000
# 1er Quartile:       0.1672
# Médiane:            0.2979
# 3ème Quartile:      0.3913
# Maximum:            0.7333

# %%
lm = pd.read_csv("Loughran-McDonald_MasterDictionary_1993-2024.csv")

neg_words = lm.query("Negative > 0")
neg_words = neg_words['Word'].str.lower().tolist()
pos_words = lm.query("Positive > 0")
pos_words = pos_words['Word'].str.lower().tolist()

# %%
from collections import Counter


pos_words_stemmed = set([porter.stem(w.lower()) for w in pos_words])
neg_words_stemmed = set([porter.stem(w.lower()) for w in neg_words])

# Compteur global
neg_counter = Counter()
pos_counter = Counter()

for text in df['clean_text'].dropna():
    tokens = str(text).split()
    # On vérifie chaque mot
    for t in tokens:
        if t in neg_words_stemmed:
            neg_counter[t] += 1
        if t in pos_words_stemmed:
            pos_counter[t] += 1

# %%
from collections import Counter

# On définit la taille de la fenêtre ici (8 mots)
N_FOLLOWERS = 8

try:
    texts = df['clean_text']
    full_text = " ".join(texts).lower().split()

    # --- CORRECTION ICI ---
    # On arrête la boucle N_FOLLOWERS avant la fin pour éviter le crash
    limit = len(full_text) - N_FOLLOWERS

    top_negative = neg_counter.most_common(100)

    print(f"--- ANALYSE DE CONTEXTE SUR LE TOP 50 POSITIF ({N_FOLLOWERS} mots suivants) ---")

    for word_tuple in top_negative:
        target_word = word_tuple[0]
        freq_global = word_tuple[1]

        followers = []

        # On boucle seulement jusqu'à la limite sécurisée
        for i in range(limit):
            if full_text[i] == target_word:
                # On capture les N mots suivants proprement
                # Slice: de i+1 jusqu'à i+1+N
                ngram_list = full_text[i+1 : i+1+N_FOLLOWERS]
                ngram = " ".join(ngram_list)
                followers.append(ngram)

        common_followers = Counter(followers).most_common(7)

        if common_followers:
            print(f"\nMot : '{target_word.upper()}' (Total: {freq_global})")
            print(f"   Contexte : {target_word} ...")
            for next_word, count in common_followers:
                pct = (count / len(followers)) * 100 if len(followers) > 0 else 0
                print(f"      -> {next_word} ({count} fois | {pct:.1f}%)")

except Exception as e:
    print(f"Erreur : {e}")
# Out:
# --- ANALYSE DE CONTEXTE SUR LE TOP 50 POSITIF (8 mots suivants) ---
#
# Mot : 'CLOSE' (Total: 596)
#    Contexte : close ...
#       -> medium term order reap full benefit monetari polici (16 fois | 2.7%)
#       -> medium term firm anchor inflat expect remain essenc (14 fois | 2.3%)
#       -> let explain assess greater detail start econom analysi (13 fois | 2.2%)
#       -> medium term anchor prerequisit monetari polici make contribut (9 fois | 1.5%)
#       -> within project horizon converg consist reflect underli inflat (9 fois | 1.5%)
#       -> develop period ahead allow explain assess greater detail (8 fois | 1.3%)
#       -> without undu delay monetari polici focus maintain price (8 fois | 1.3%)
#
# Mot : 'DECLIN' (Total: 516)
#    Contexte : declin ...
#       -> resili bank strengthen need decis step establish bank (4 fois | 0.8%)
#       -> inflat sinc last summer primarili reflect sharp fall (3 fois | 0.6%)
#       -> much less neg rate stabilis phase posit quarterli (3 fois | 0.6%)
#       -> euro area econom activ expand sinc mid- euro (3 fois | 0.6%)
#       -> cours next year policy-relev horizon environ modest growth (3 fois | 0.6%)
#       -> measur predict pace eurosystem reinvest princip payment matur (3 fois | 0.6%)
#       -> still expect remain high long determin ensur inflat (3 fois | 0.6%)
#
# Mot : 'LIQUID' (Total: 456)
#    Contexte : liquid ...
#       -> cross-check outcom econom analysi monetari analysi support assess (13 fois | 2.9%)
#       -> point upsid risk price stabil medium longer term (6 fois | 1.3%)
#       -> allot mode adjust appropri take account fact non-standard (6 fois | 1.3%)
#       -> euro area ampl plausibl measur therefor look ahead (5 fois | 1.1%)
#       -> form money continu main contributor broad money growth (5 fois | 1.1%)
#       -> money-hold sector low opportun cost hold liquid form (5 fois | 1.1%)
#       -> situat euro area ampl plausibl measur continu strong (4 fois | 0.9%)
#
# Mot : 'PRESS' (Total: 340)
#    Contexte : press ...
#       -> confer report outcom today meet govern council also (54 fois | 15.9%)
#       -> confer report outcom today meet govern council base (23 fois | 6.8%)
#       -> releas avail websit outlin detail see economi inflat (22 fois | 6.5%)
#       -> confer report outcom today meet ecb govern council (10 fois | 2.9%)
#       -> confer govern council today decid keep three key (8 fois | 2.4%)
#       -> confer report outcom today meet base regular econom (6 fois | 1.8%)
#       -> confer govern council today decid lower three key (6 fois | 1.8%)
#
# Mot : 'WEAK' (Total: 297)
#    Contexte : weak ...
#       -> money credit growth overal expect price stabil maintain (10 fois | 3.4%)
#       -> loan dynam non-financi corpor continu reflect lag relationship (7 fois | 2.4%)
#       -> annual growth rate loan household adjust loan sale (5 fois | 1.7%)
#       -> outlook gdp heighten risk avers ongo adjust balanc (4 fois | 1.3%)
#       -> loan dynam continu reflect primarili current stage busi (4 fois | 1.3%)
#       -> acceler green digit transit readi take christin lagard (4 fois | 1.3%)
#       -> togeth data continu support assess underli pace monetari (3 fois | 1.0%)
#
# Mot : 'CONCERN' (Total: 257)
#    Contexte : concern ...
#       -> exist scheme nomin wage index consum price scheme (8 fois | 3.1%)
#       -> govern council therefor call scheme avoid monetari analysi (5 fois | 1.9%)
#       -> remain relat stronger protract neg feedback loop real (5 fois | 1.9%)
#       -> possibl disorderli develop owe global imbal regard price (4 fois | 1.6%)
#       -> protectionist pressur possibl disorderli develop owe global imbal (4 fois | 1.6%)
#       -> remain relat stronger protract expect neg feedback loop (4 fois | 1.6%)
#       -> forward guidanc key ecb interest rate remain present (3 fois | 1.2%)
#
# Mot : 'DAMPEN' (Total: 242)
#    Contexte : dampen ...
#       -> demand expect econom environ rest world worsen unexpectedli (10 fois | 4.1%)
#       -> impact consumpt invest unanticip increas energi food price (5 fois | 2.1%)
#       -> impact overal growth reduc attract monetari asset compar (5 fois | 2.1%)
#       -> process balanc sheet adjust variou sector govern council (4 fois | 1.7%)
#       -> pace econom growth euro area second half year (4 fois | 1.7%)
#       -> necessari balanc sheet adjust number sector sluggish pace (4 fois | 1.7%)
#       -> demand also guard risk persist upward shift inflat (4 fois | 1.7%)
#
# Mot : 'IMBAL' (Total: 233)
#    Contexte : imbal ...
#       -> regard price develop euro area annual hicp inflat (18 fois | 7.7%)
#       -> regard price develop accord eurostat flash estim annual (12 fois | 5.2%)
#       -> procedur time across countri remain essenti increas resili (7 fois | 3.0%)
#       -> region world potenti repercuss sustain global econom growth (3 fois | 1.3%)
#       -> turn price develop accord eurostat flash estim annual (3 fois | 1.3%)
#       -> regard price develop annual hicp inflat accord eurostat (3 fois | 1.3%)
#       -> may weigh downsid regard price develop euro area (3 fois | 1.3%)
#
# Mot : 'VOLATIL' (Total: 224)
#    Contexte : volatil ...
#       -> inflat rate relev horizon monetari polici medium term (5 fois | 2.2%)
#       -> quarterli growth rate like emerg around turn year (3 fois | 1.3%)
#       -> increas uncertainti regard financi market continu pay great (3 fois | 1.3%)
#       -> financi market broad assess underli trend money credit (3 fois | 1.3%)
#       -> risk avers financi market would weigh domest demand (3 fois | 1.3%)
#       -> global trade polici environ stronger euro could bring (3 fois | 1.3%)
#       -> oil price persist global imbal pose downsid risk (2 fois | 0.9%)
#
# Mot : 'NEG' (Total: 209)
#    Contexte : neg ...
#       -> feedback loop real economi financi sector renew increas (10 fois | 4.8%)
#       -> affect econom condit downsid risk includ higher commod (5 fois | 2.4%)
#       -> inflat rate short-liv price stabil maintain medium term (4 fois | 1.9%)
#       -> pandem shock path inflat continu reinvest princip payment (4 fois | 1.9%)
#       -> rate stabilis phase posit quarterli growth rate expect (3 fois | 1.4%)
#       -> downsid risk includ weaker expect domest demand insuffici (3 fois | 1.4%)
#       -> growth econom activ remaind year expect declin much (2 fois | 1.0%)
#
# Mot : 'UNEMPLOY' (Total: 204)
#    Contexte : unemploy ...
#       -> boost euro area product growth potenti regard fiscal (10 fois | 4.9%)
#       -> low potenti output growth euro area ongo cyclic (8 fois | 3.9%)
#       -> euro area remain high necessari balanc sheet adjust (5 fois | 2.5%)
#       -> increas resili country-specif recommend serv relev signpost regard (5 fois | 2.5%)
#       -> remain high euro area overal unutilis capac continu (4 fois | 2.0%)
#       -> boost potenti output growth euro area structur reform (4 fois | 2.0%)
#       -> situat loss competit reform strengthen product growth would (3 fois | 1.5%)
#
# Mot : 'CRUCIAL' (Total: 168)
#    Contexte : crucial ...
#       -> maintain confid fiscal framework time countri strive growth-friendli (5 fois | 3.0%)
#       -> social partner continu meet respons context wage agreement (4 fois | 2.4%)
#       -> element move toward re-integr bank system therefor requir (4 fois | 2.4%)
#       -> social partner continu meet respons also context favour (3 fois | 1.8%)
#       -> price wage-sett fulli live respons turn monetari analysi (3 fois | 1.8%)
#       -> focu strengthen adjust capac flexibl euro area economi (3 fois | 1.8%)
#       -> move toward re-integr bank system sum econom analysi (3 fois | 1.8%)
#
# Mot : 'WEAKER' (Total: 165)
#    Contexte : weaker ...
#       -> expect growth euro area global turn monetari analysi (4 fois | 2.4%)
#       -> expect domest global demand slow insuffici implement structur (4 fois | 2.4%)
#       -> expect domest demand export growth slow insuffici implement (4 fois | 2.4%)
#       -> world economi slowdown global trade would also weigh (4 fois | 2.4%)
#       -> world economi escal trade tension major economi would (4 fois | 2.4%)
#       -> expect develop econom activ monetari analysi indic underli (3 fois | 1.8%)
#       -> expect domest demand insuffici implement structur reform euro (3 fois | 1.8%)
#
# Mot : 'DEFICIT' (Total: 156)
#    Contexte : deficit ...
#       -> debt ratio annual structur adjust reach least gdp (4 fois | 2.6%)
#       -> measur ensur wage bargain process allow wage adjust (3 fois | 1.9%)
#       -> debt place addit burden monetari polici undermin stabil (2 fois | 1.3%)
#       -> procedur consolid public financ start latest exceed substanti (2 fois | 1.3%)
#       -> remov labour market rigid strengthen product growth would (2 fois | 1.3%)
#       -> remov labour market rigid would support adjust process (2 fois | 1.3%)
#       -> debt ratio sustain basi govern make strong start (2 fois | 1.3%)
#
# Mot : 'SEVER' (Total: 154)
#    Contexte : sever ...
#       -> year robust monetari growth liquid situat euro area (10 fois | 6.5%)
#       -> euro area financi market potenti spillov euro area (5 fois | 3.2%)
#       -> part euro area howev growth loan non-financi corpor (4 fois | 2.6%)
#       -> indic higher short-term interest rate influenc monetari dynam (3 fois | 1.9%)
#       -> euro area countri remain substanti liquid euro area (2 fois | 1.3%)
#       -> downturn global euro area demand like remain weak (2 fois | 1.3%)
#       -> downturn prospect extern domest demand remain weak gradual (2 fois | 1.3%)
#
# Mot : 'DOWNWARD' (Total: 148)
#    Contexte : downward ...
#       -> impact pandem project path inflat addit flexibl purchas (5 fois | 3.4%)
#       -> pressur inflat upsid risk price stabil could materialis (3 fois | 2.0%)
#       -> risk econom outlook accord eurostat flash estim euro (3 fois | 2.0%)
#       -> pressur price short term pattern risk price stabil (2 fois | 1.4%)
#       -> risk relat mainli oil price concern global imbal (2 fois | 1.4%)
#       -> trend observ past year result higher short-term interest (2 fois | 1.4%)
#       -> impact steep yield curv associ alloc fund longer-term (2 fois | 1.4%)
#
# Mot : 'PERSIST' (Total: 135)
#    Contexte : persist ...
#       -> uncertainti relat geopolit factor threat protection vulner emerg (6 fois | 4.4%)
#       -> upward trend underli rate monetari expans identifi ecb (3 fois | 2.2%)
#       -> upward trend underli rate monetari expans follow sever (3 fois | 2.2%)
#       -> rise inflat expect target higher anticip wage rise (3 fois | 2.2%)
#       -> imbal region world potenti repercuss sustain global econom (2 fois | 1.5%)
#       -> could lead inflationari pressur medium term sum econom (2 fois | 1.5%)
#       -> domest price pressur expect remain low latest inform (2 fois | 1.5%)
#
# Mot : 'OBJECT' (Total: 133)
#    Contexte : object ...
#       -> govern council remain strongli commit prevent second-round effect (5 fois | 3.8%)
#       -> environ accommod monetari polici swift effect implement structur (5 fois | 3.8%)
#       -> strong determin keep medium long-term inflat expect firmli (4 fois | 3.0%)
#       -> support sustain growth employ contribut financi stabil accordingli (4 fois | 3.0%)
#       -> continu monitor close develop period ahead allow explain (3 fois | 2.3%)
#       -> continu monitor close develop period ahead regard fiscal (3 fois | 2.3%)
#       -> futur singl supervisori mechan ssm one main build (3 fois | 2.3%)
#
# Mot : 'WEAKEN' (Total: 131)
#    Contexte : weaken ...
#       -> econom activ euro area global latest econom data (4 fois | 3.1%)
#       -> demand upsid risk price stabil diminish somewhat disappear (3 fois | 2.3%)
#       -> real gdp growth mid- part expect except strong (2 fois | 1.5%)
#       -> real gdp growth mid- reflect partli expect technic (2 fois | 1.5%)
#       -> econom activ euro area global recent survey inform (2 fois | 1.5%)
#       -> annual growth rate loan household adjust loan sale (2 fois | 1.5%)
#       -> euro area growth momentum recent past continu subdu (2 fois | 1.5%)
#
# Mot : 'EAS' (Total: 122)
#    Contexte : eas ...
#       -> firmli reiter continu expect key ecb interest rate (2 fois | 1.6%)
#       -> monetari polici stanc broadli support forward guidanc key (2 fois | 1.6%)
#       -> support favour financ condit expansionari fiscal stanc resumpt (2 fois | 1.6%)
#       -> overal monetari polici stanc therebi help offset downward (2 fois | 1.6%)
#       -> past interest rate increas continu transmit forc financ (2 fois | 1.6%)
#       -> labour cost pressur continu impact past monetari polici (2 fois | 1.6%)
#       -> financ condit come past interest rate hike still (2 fois | 1.6%)
#
# Mot : 'SHOCK' (Total: 117)
#    Contexte : shock ...
#       -> ensur adequ access financ therebi lay foundat sustain (9 fois | 7.7%)
#       -> inflat lead wage-pric spiral would detriment employ competit (8 fois | 6.8%)
#       -> fiscal polici also support econom recoveri remain complianc (6 fois | 5.1%)
#       -> therebi lay foundat sustain econom growth financi stabil (5 fois | 4.3%)
#       -> path inflat continu reinvest princip payment matur secur (4 fois | 3.4%)
#       -> inde reform aim reduc rigid labour good market (2 fois | 1.7%)
#       -> euro area whole region renew momentum process structur (2 fois | 1.7%)
#
# Mot : 'CORRECT' (Total: 114)
#    Contexte : correct ...
#       -> global imbal regard price develop euro area annual (18 fois | 15.8%)
#       -> global imbal regard price develop annual hicp inflat (6 fois | 5.3%)
#       -> global imbal may weigh downsid regard price develop (3 fois | 2.6%)
#       -> measur must implement swiftli ensur progress achiev fiscal (3 fois | 2.6%)
#       -> financi non-financi sector economi insid outsid euro area (2 fois | 1.8%)
#       -> global imbal regard price develop expect euro area (2 fois | 1.8%)
#       -> action decis step establish bank union help restor (2 fois | 1.8%)
#
# Mot : 'SLOW' (Total: 113)
#    Contexte : slow ...
#       -> insuffici implement structur reform euro area countri accord (8 fois | 7.1%)
#       -> insuffici implement structur reform euro area factor potenti (3 fois | 2.7%)
#       -> pace particular owe gradual improv domest demand support (3 fois | 2.7%)
#       -> time growth loan household continu follow downward trend (2 fois | 1.8%)
#       -> assess take account advers lag effect deterior labour (2 fois | 1.8%)
#       -> background expect price stabil maintain medium term therebi (2 fois | 1.8%)
#       -> expect price stabil maintain medium term therebi support (2 fois | 1.8%)
#
# Mot : 'CHALLENG' (Total: 113)
#    Contexte : challeng ...
#       -> necessari essenti bank retain earn turn market strengthen (8 fois | 7.1%)
#       -> remain bank expand avail credit non-financi sector demand (6 fois | 5.3%)
#       -> bank retain earn turn market strengthen capit base (5 fois | 4.4%)
#       -> bank use improv fund condit strengthen capit base (4 fois | 3.5%)
#       -> lie ahead bank take appropri measur strengthen capit (3 fois | 2.7%)
#       -> bank take appropri measur strengthen capit base necessari (3 fois | 2.7%)
#       -> time appli first foremost role ensur monetari polici (3 fois | 2.7%)
#
# Mot : 'EXCESS' (Total: 105)
#    Contexte : excess ...
#       -> liquid persist could lead inflationari pressur medium term (4 fois | 3.8%)
#       -> deficit procedur consolid public financ start latest exceed (2 fois | 1.9%)
#       -> imbal identifi individu member state mario draghi presid (2 fois | 1.9%)
#       -> refer valu signal rather gener liquid situat euro (1 fois | 1.0%)
#       -> demand loan remain strong throughout first three quarter (1 fois | 1.0%)
#       -> wage claim inde stability-ori behaviour urgent requir conclus (1 fois | 1.0%)
#       -> wage increas unsustain expans profit margin expansionari stanc (1 fois | 1.0%)
#
# Mot : 'DISPOS' (Total: 105)
#    Contexte : dispos ...
#       -> incom corpor profit therefor privat consumpt invest furthermor (3 fois | 2.9%)
#       -> incom privat consumpt addit fiscal stanc euro area (3 fois | 2.9%)
#       -> incom usual lag underpin increas employ growth later (2 fois | 1.9%)
#       -> incom time outlook econom activ remain subject downward (2 fois | 1.9%)
#       -> incom employ condit continu improv risk outlook econom (2 fois | 1.9%)
#       -> incom employ condit continu improv outlook also reflect (2 fois | 1.9%)
#       -> incom increasingli support employ growth improv labour market (2 fois | 1.9%)
#
# Mot : 'ADVERS' (Total: 103)
#    Contexte : advers ...
#       -> develop world economi stem disorderli correct global imbal (8 fois | 7.8%)
#       -> lag effect deterior labour market like materialis come (6 fois | 5.8%)
#       -> affect outlook henc cross-check inform two pillar lead (2 fois | 1.9%)
#       -> affect outlook time overal therefor medium-term outlook price (2 fois | 1.9%)
#       -> develop like materialis come month deterior labour market (2 fois | 1.9%)
#       -> weather condit particular dampen growth earli part year (2 fois | 1.9%)
#       -> impact domest expenditur weak consum investor sentiment subdu (2 fois | 1.9%)
#
# Mot : 'TIGHTEN' (Total: 103)
#    Contexte : tighten ...
#       -> financ condit inconsist counter downward impact pandem project (5 fois | 4.9%)
#       -> labour market look ahead underli inflat expect increas (4 fois | 3.9%)
#       -> credit standard report bank lend survey euro area (3 fois | 2.9%)
#       -> financ condit slower econom growth bank borrow euro (2 fois | 1.9%)
#       -> remain essenti monetari polici focu mandat maintain price (2 fois | 1.9%)
#       -> financ condit reinforc conclus sum euro area economi (2 fois | 1.9%)
#       -> broader credit condit strongli expect dampen confid russia (2 fois | 1.9%)
#
# Mot : 'LAG' (Total: 89)
#    Contexte : lag ...
#       -> relationship busi cycl credit risk ongo adjust financi (20 fois | 22.5%)
#       -> relationship busi cycl credit risk credit suppli factor (13 fois | 14.6%)
#       -> effect deterior labour market like materialis come month (6 fois | 6.7%)
#       -> polici action progress feed economi full henc measur (4 fois | 4.5%)
#       -> expect polici action progress feed economi full henc (2 fois | 2.2%)
#       -> respons loan non-financi corpor econom activ normal featur (2 fois | 2.2%)
#       -> respons loan non-financi corpor develop econom activ normal (2 fois | 2.2%)
#
# Mot : 'CONTRACT' (Total: 88)
#    Contexte : contract ...
#       -> clearli slow assess take account advers lag effect (2 fois | 2.3%)
#       -> econom activ come end follow period stabilis gradual (2 fois | 2.3%)
#       -> quarter quarter second quarter follow flat growth previou (2 fois | 2.3%)
#       -> quarter quarter second quarter euro area real gdp (2 fois | 2.3%)
#       -> quarter quarter declin larg due fall domest demand (2 fois | 2.3%)
#       -> euro area economi measur taken much possibl target (2 fois | 2.3%)
#       -> recoveri depend crucial durat effect contain measur success (2 fois | 2.3%)
#
# Mot : 'SUBJECT' (Total: 83)
#    Contexte : subject ...
#       -> particularli high uncertainti intensifi downsid risk time short-term (4 fois | 4.8%)
#       -> high uncertainti substanti downsid risk environ cost wage (3 fois | 3.6%)
#       -> downward risk relat mainli oil price concern global (2 fois | 2.4%)
#       -> upsid risk background money credit growth vigor euro (2 fois | 2.4%)
#       -> high uncertainti medium longer-term inflat expect remain firmli (2 fois | 2.4%)
#       -> uncertainti outcom monetari analysi confirm assess low inflationari (2 fois | 2.4%)
#       -> uncertainti cross-check outcom econom analysi monetari analysi confirm (2 fois | 2.4%)
#
# Mot : 'STRESS' (Total: 79)
#    Contexte : stress ...
#       -> countri reduc relianc eurosystem reflect repay three-year ltro (3 fois | 3.8%)
#       -> countri order ensur adequ transmiss monetari polici financ (3 fois | 3.8%)
#       -> import becom oper without delay call member state (3 fois | 3.8%)
#       -> previou occas anchor prerequisit monetari polici make ongo (2 fois | 2.5%)
#       -> urgent need strengthen euro area economi present geopolit (2 fois | 2.5%)
#       -> recent develop bond yield euro area accompani decoupl (1 fois | 1.3%)
#       -> low inflat therefor low interest rate encourag higher (1 fois | 1.3%)
#
# Mot : 'LIMIT' (Total: 72)
#    Contexte : limit ...
#       -> access market financ urgent need increas capit effici (6 fois | 8.3%)
#       -> broadli balanc medium term context close monitor possibl (3 fois | 4.2%)
#       -> risk medium-term outlook price develop remain broadli balanc (2 fois | 2.8%)
#       -> risk outlook hicp inflat rate come year still (2 fois | 2.8%)
#       -> broadli balanc medium term context possibl repercuss geopolit (2 fois | 2.8%)
#       -> implement country-specif recommend greater reform effort necessari euro (2 fois | 2.8%)
#       -> evid yet activ may seen turnaround cours first (1 fois | 1.4%)
#
# Mot : 'DELAY' (Total: 71)
#    Contexte : delay ...
#       -> monetari polici focus maintain price stabil medium term (8 fois | 11.3%)
#       -> help govern bring budget deficit debt ratio sustain (5 fois | 7.0%)
#       -> recoveri accord eurostat flash estim euro area annual (4 fois | 5.6%)
#       -> pass-through inflat medium term inflat expect increas support (3 fois | 4.2%)
#       -> recoveri privat invest employ consumpt accord eurostat flash (2 fois | 2.8%)
#       -> order reap full benefit monetari polici measur polici (2 fois | 2.8%)
#       -> call member state ensur time ratif resourc decis (2 fois | 2.8%)
#
# Mot : 'QUESTION' (Total: 68)
#    Contexte : question ...
#       -> answer ladi gentlemen vice-presid report outcom today 's (30 fois | 44.1%)
#       -> answer ladi gentlemen vice-presid today report outcom today (11 fois | 16.2%)
#       -> answer ladi gentlemen vice-presid report outcom today meet (5 fois | 7.4%)
#       -> answer ladi gentlemen govern council european central bank (4 fois | 5.9%)
#       -> answer ladi gentlemen vice-presid today report outcom first (1 fois | 1.5%)
#       -> possibl seek limit domest payment activ much possibl (1 fois | 1.5%)
#       -> answer ladi gentlemen vice-presid report today 's meet (1 fois | 1.5%)
#
# Mot : 'IMPLIC' (Total: 68)
#    Contexte : implic ...
#       -> medium-term inflat outlook stand readi adjust instrument appropri (4 fois | 5.9%)
#       -> mainten price stabil euro area govern council decid (3 fois | 4.4%)
#       -> medium-term outlook price stabil substanti degre monetari accommod (3 fois | 4.4%)
#       -> econom financi condit continu sourc downsid risk euro (3 fois | 4.4%)
#       -> risk futur price stabil euro area subsequ decid (2 fois | 2.9%)
#       -> mainten price stabil euro area decid leav minimum (2 fois | 2.9%)
#       -> mainten price stabil euro area decis keep interest (2 fois | 2.9%)
#
# Mot : 'DIMINISH' (Total: 67)
#    Contexte : diminish ...
#       -> today decis expect price stabil maintain medium term (4 fois | 6.0%)
#       -> somewhat disappear still strong underli pace monetari expans (2 fois | 3.0%)
#       -> level uncertainti remain except high govern council continu (2 fois | 3.0%)
#       -> owe mainli base effect stem past behaviour energi (2 fois | 3.0%)
#       -> continu expect inflat rate euro area line price (2 fois | 3.0%)
#       -> money credit growth deceler recent month background develop (2 fois | 3.0%)
#       -> remain trade disput resolv faster expect outlook inflat (2 fois | 3.0%)
#
# Mot : 'RESTRUCTUR' (Total: 67)
#    Contexte : restructur ...
#       -> accumul ongo strong earn gain busi effici consumpt (6 fois | 9.0%)
#       -> bank sector play import role sound balanc sheet (4 fois | 6.0%)
#       -> accumul ongo gain earn busi effici consumpt growth (3 fois | 4.5%)
#       -> labour market reform help facilit appropri wage-set well (3 fois | 4.5%)
#       -> gain earn busi effici consumpt growth also strengthen (2 fois | 3.0%)
#       -> accumul ongo strong corpor earn gain busi effici (2 fois | 3.0%)
#       -> well busi effici gain achiev extend period meanwhil (2 fois | 3.0%)
#
# Mot : 'DISORDERLI' (Total: 67)
#    Contexte : disorderli ...
#       -> correct global imbal regard price develop euro area (18 fois | 26.9%)
#       -> develop owe global imbal regard price develop accord (9 fois | 13.4%)
#       -> correct global imbal regard price develop annual hicp (6 fois | 9.0%)
#       -> develop due global imbal regard price develop accord (4 fois | 6.0%)
#       -> develop owe global imbal also impli downsid risk (3 fois | 4.5%)
#       -> correct global imbal may weigh downsid regard price (3 fois | 4.5%)
#       -> develop owe global imbal potenti shift financi market (2 fois | 3.0%)
#
# Mot : 'CRISI' (Total: 66)
#    Contexte : crisi ...
#       -> broadli could drive food price expect financi monetari (5 fois | 7.6%)
#       -> broadli could drive food price contrast inflat may (4 fois | 6.1%)
#       -> phase reinvest princip payment matur secur purchas pepp (3 fois | 4.5%)
#       -> fade govern roll back relat support measur promptli (3 fois | 4.5%)
#       -> fade govern continu roll back relat support measur (3 fois | 4.5%)
#       -> therebi support effect monetari polici euro area target (2 fois | 3.0%)
#       -> phase base joint assess financ condit inflat outlook (2 fois | 3.0%)
#
# Mot : 'VULNER' (Total: 66)
#    Contexte : vulner ...
#       -> implement structur reform euro area countri need substanti (15 fois | 22.7%)
#       -> emerg market accord eurostat flash estim euro area (4 fois | 6.1%)
#       -> implement structur polici euro area countri need substanti (4 fois | 6.1%)
#       -> enhanc resili preserv macroprudenti space conclus govern council (3 fois | 4.5%)
#       -> implement structur reform need substanti step increas resili (2 fois | 3.0%)
#       -> emerg market financi market volatil gain promin recent (2 fois | 3.0%)
#       -> emerg market financi market volatil remain promin signific (2 fois | 3.0%)
#
# Mot : 'SLOWDOWN' (Total: 61)
#    Contexte : slowdown ...
#       -> global trade would also weigh euro area growth (4 fois | 6.6%)
#       -> extern demand compound countri sector-specif factor impact factor (3 fois | 4.9%)
#       -> larg relat effect intensif broaden financi turmoil global (2 fois | 3.3%)
#       -> economi could put downward pressur inflat upsid risk (2 fois | 3.3%)
#       -> compar two previou month develop line previou trend (1 fois | 1.6%)
#       -> appar industri product growth novemb particular intermedi good (1 fois | 1.6%)
#       -> compar novemb octob develop line previou trend e (1 fois | 1.6%)
#
# Mot : 'TURMOIL' (Total: 61)
#    Contexte : turmoil ...
#       -> thu far data analysi requir order obtain complet (4 fois | 6.6%)
#       -> global demand euro area demand like dampen protract (3 fois | 4.9%)
#       -> time howev littl evid financi market turbul sinc (2 fois | 3.3%)
#       -> financi market remain unusu high tension may last (2 fois | 3.3%)
#       -> possibl impact econom activ inflat recognis extraordinarili high (2 fois | 3.3%)
#       -> like dampen global euro area demand rather protract (2 fois | 3.3%)
#       -> financi market well concern emerg intensif protectionist pressur (2 fois | 3.3%)
#
# Mot : 'PREVENT' (Total: 58)
#    Contexte : prevent ...
#       -> second-round effect materialis upsid risk price stabil medium (8 fois | 13.8%)
#       -> tighten financ condit inconsist counter downward impact pandem (5 fois | 8.6%)
#       -> consumpt invest recov fast expect monetari polici dampen (3 fois | 5.2%)
#       -> repeat past experi complac good time contribut persist (2 fois | 3.4%)
#       -> second-round effect ensur risk price stabil medium term (2 fois | 3.4%)
#       -> recent price develop give rise broad-bas inflationari pressur (2 fois | 3.4%)
#       -> balanc sheet strain tighten financ condit reinforc conclus (2 fois | 3.4%)
#
# Mot : 'PROLONG' (Total: 57)
#    Contexte : prolong ...
#       -> period low inflat follow gradual upward movement toward (10 fois | 17.5%)
#       -> period low inflat follow gradual upward movement hicp (5 fois | 8.8%)
#       -> presenc uncertainti relat geopolit factor rise threat protection (5 fois | 8.8%)
#       -> period low inflat govern council unanim commit use (3 fois | 5.3%)
#       -> period time support underli inflat pressur headlin inflat (3 fois | 5.3%)
#       -> period low inflat strongli determin safeguard firm anchor (2 fois | 3.5%)
#       -> global uncertainti particularli affect euro area manufactur sector (2 fois | 3.5%)
#
# Mot : 'LOSS' (Total: 54)
#    Contexte : loss ...
#       -> competit past suffer high fiscal extern deficit remov (4 fois | 7.4%)
#       -> past suffer high fiscal extern deficit measur ensur (3 fois | 5.6%)
#       -> competit reform strengthen product growth would support adjust (3 fois | 5.6%)
#       -> purchas power caus higher energi food price view (2 fois | 3.7%)
#       -> cost price competit recent year unemploy alreadi start (2 fois | 3.7%)
#       -> real incom avoid economi whole attempt shift burden (1 fois | 1.9%)
#       -> within economi risk endang continu non-inflationari growth process (1 fois | 1.9%)
#
# Mot : 'PROTRACT' (Total: 49)
#    Contexte : protract ...
#       -> expect neg feedback loop real economi financi sector (7 fois | 14.3%)
#       -> period time environ take account strong fall commod (2 fois | 4.1%)
#       -> neg feedback loop real economi turmoil financi market (2 fois | 4.1%)
#       -> neg feedback loop real economi financi sector renew (2 fois | 4.1%)
#       -> foreseen earlier henc indic risk second round effect (1 fois | 2.0%)
#       -> commod produc price increas heighten risk second round (1 fois | 2.0%)
#       -> increas import produc price consum price need assess (1 fois | 2.0%)
#
# Mot : 'LIE' (Total: 49)
#    Contexte : lie ...
#       -> downsid downsid risk relat mainli potenti broader impact (3 fois | 6.1%)
#       -> ahead bank take appropri measur strengthen capit base (3 fois | 6.1%)
#       -> mainli downsid main risk relat fear rise protectionist (2 fois | 4.1%)
#       -> upsid risk includ possibl stronger current expect wage (2 fois | 4.1%)
#       -> ahead expect bank sector make contribut restor confid (2 fois | 4.1%)
#       -> govern well key nation econom agent side labour (1 fois | 2.0%)
#       -> european commiss minist financ govern council fulli support (1 fois | 2.0%)
#
# Mot : 'DETERIOR' (Total: 48)
#    Contexte : deterior ...
#       -> financi market sentiment could lead tighter financ condit (5 fois | 10.4%)
#       -> labour market like materialis come month look ahead (4 fois | 8.3%)
#       -> labour market time avail indic inflat expect medium (2 fois | 4.2%)
#       -> labour market like materialis come month time avail (2 fois | 4.2%)
#       -> may less mark previous expect foreign demand may (2 fois | 4.2%)
#       -> extern environ howev time product capit good consum (1 fois | 2.1%)
#       -> partial inform cover substanti part euro area appear (1 fois | 2.1%)
#
# Mot : 'URGENT' (Total: 47)
#    Contexte : urgent ...
#       -> need speed restructur invest creat new busi opportun (3 fois | 6.4%)
#       -> need increas capit effici sum base regular econom (3 fois | 6.4%)
#       -> need speed restructur invest creat busi opportun product (2 fois | 4.3%)
#       -> implement far-reach structur reform essenti enhanc prospect higher (2 fois | 4.3%)
#       -> need increas capit effici sum govern council decid (2 fois | 4.3%)
#       -> fiscal structur polici make euro area economi product (2 fois | 4.3%)
#       -> strengthen euro area economi present geopolit environ fiscal (2 fois | 4.3%)
#
# Mot : 'FORC' (Total: 47)
#    Contexte : forc ...
#       -> particip increas significantli unemploy rate fallen level seen (4 fois | 8.5%)
#       -> euro area financ monetari condit lag strength transmiss (2 fois | 4.3%)
#       -> financ condit tighten increasingli dampen demand import factor (2 fois | 4.3%)
#       -> financ condit increasingli dampen demand therebi help push (2 fois | 4.3%)
#       -> underli solid growth medium term remain place relat (1 fois | 2.1%)
#       -> balanc govern council judg risk price stabil still (1 fois | 2.1%)
#       -> economi provid proper incent econom agent govern council (1 fois | 2.1%)
#
# Mot : 'POSE' (Total: 45)
#    Contexte : pose ...
#       -> signific upward risk price stabil least view favour (3 fois | 6.7%)
#       -> substanti upward risk price stabil background crucial social (2 fois | 4.4%)
#       -> upward risk price stabil therefor crucial parti concern (2 fois | 4.4%)
#       -> seriou risk public health euro area global economi (2 fois | 4.4%)
#       -> threat favour outlook price growth employ prospect credibl (1 fois | 2.2%)
#       -> risk world economi euro area particular continu undervalu (1 fois | 2.2%)
#       -> upward risk price stabil medium term still present (1 fois | 2.2%)
#
# Mot : 'SLOWER' (Total: 45)
#    Contexte : slower ...
#       -> underli pace monetari expans low inflationari pressur medium (3 fois | 6.7%)
#       -> growth global activ risk surround euro area growth (3 fois | 6.7%)
#       -> econom growth bank borrow euro area non-financi corpor (2 fois | 4.4%)
#       -> expans global activ risk surround euro area growth (2 fois | 4.4%)
#       -> effect monetari polici forc expect world economi weaken (2 fois | 4.4%)
#       -> previous expect develop use electron money second govern (1 fois | 2.2%)
#       -> growth may determin govern countri adher strictli stabil (1 fois | 2.2%)
#
# Mot : 'DROP' (Total: 44)
#    Contexte : drop ...
#       -> markedli septemb includ due strong base effect measur (2 fois | 4.5%)
#       -> annual inflat rate current junctur two main consider (1 fois | 2.3%)
#       -> oil price like reflect price statist april outlook (1 fois | 2.3%)
#       -> calcul annual rate februari come month volatil annual (1 fois | 2.3%)
#       -> background ecb staff project put averag annual hicp (1 fois | 2.3%)
#       -> sever upward risk outlook price stabil continu exist (1 fois | 2.3%)
#       -> global commod price year ago inflat expect rise (1 fois | 2.3%)
#
# Mot : 'CUT' (Total: 41)
#    Contexte : cut ...
#       -> consid medium term countri regain suffici room budgetari (2 fois | 4.9%)
#       -> gradual make new borrow less expens firm household (2 fois | 4.9%)
#       -> gradual make less expens firm household borrow averag (2 fois | 4.9%)
#       -> continu make corpor borrow less expens averag interest (2 fois | 4.9%)
#       -> fiscal deficit enhanc structur reform inde creation virtuou (1 fois | 2.4%)
#       -> welcom current budgetari plan forese insuffici spend restraint (1 fois | 2.4%)
#       -> current slowdown present particular challeng countri yet attain (1 fois | 2.4%)
#
# Mot : 'DISRUPT' (Total: 39)
#    Contexte : disrupt ...
#       -> global trade moreov extrem weather event unfold climat (6 fois | 15.4%)
#       -> market movement relat correct global imbal regard price (2 fois | 5.1%)
#       -> growth could higher inflat come quickli expect rise (2 fois | 5.1%)
#       -> global trade inflat could also turn higher anticip (2 fois | 5.1%)
#       -> growth could also lower effect monetari polici turn (2 fois | 5.1%)
#       -> suppli chain dampen export weigh consumpt invest deterior (2 fois | 5.1%)
#       -> suppli chain reduc domest foreign demand especi advers (1 fois | 2.6%)
#
# Mot : 'SLUGGISH' (Total: 38)
#    Contexte : sluggish ...
#       -> pace implement structur reform risk euro area growth (4 fois | 10.5%)
#       -> pace implement structur reform remain balanc sheet adjust (3 fois | 7.9%)
#       -> demand euro area elsewher avail indic inflat expect (2 fois | 5.3%)
#       -> demand euro area elsewher respect indic inflat expect (2 fois | 5.3%)
#       -> demand euro area elsewher context import re-emphasis inflat (2 fois | 5.3%)
#       -> pace implement structur reform assess also broadli reflect (2 fois | 5.3%)
#       -> pace implement structur reform particular product market remain (2 fois | 5.3%)
#
# Mot : 'INSUFFICI' (Total: 37)
#    Contexte : insuffici ...
#       -> implement structur reform euro area countri accord eurostat (9 fois | 24.3%)
#       -> implement structur reform euro area factor potenti dampen (3 fois | 8.1%)
#       -> implement structur reform euro area countri well weaker (3 fois | 8.1%)
#       -> progress structur reform euro area countri constitut key (3 fois | 8.1%)
#       -> structur reform euro area countri well weaker expect (2 fois | 5.4%)
#       -> experi regard properti new esa data particular suscept (1 fois | 2.7%)
#       -> spend restraint overal medium-term outlook price stabil risk (1 fois | 2.7%)
#
# Mot : 'WORSEN' (Total: 32)
#    Contexte : worsen ...
#       -> supply-sid constraint persist high energi cost togeth loss (2 fois | 6.2%)
#       -> unexpectedli financi monetari condit market interest rate risen (2 fois | 6.2%)
#       -> unexpectedli greater friction global trade would make euro (2 fois | 6.2%)
#       -> toward end last year report met earli march (1 fois | 3.1%)
#       -> first time sinc owe macroeconom slowdown lack expenditur (1 fois | 3.1%)
#       -> financ condit stem heighten uncertainti relat sovereign debt (1 fois | 3.1%)
#       -> near-term growth outlook disrupt suppli chain imped product (1 fois | 3.1%)
#
# Mot : 'THREAT' (Total: 30)
#    Contexte : threat ...
#       -> price stabil medium longer term effect counter time (4 fois | 13.3%)
#       -> price stabil medium longer term liquid provid absorb (4 fois | 13.3%)
#       -> protection vulner emerg market accord eurostat flash estim (4 fois | 13.3%)
#       -> price stabil medium longer term govern council continu (3 fois | 10.0%)
#       -> protection vulner emerg market leav mark econom sentiment (2 fois | 6.7%)
#       -> favour outlook price growth employ prospect credibl stabil (1 fois | 3.3%)
#       -> inflat assur wage negoti prospect price stabil remain (1 fois | 3.3%)
#
# Mot : 'RECAL' (Total: 26)
#    Contexte : recal ...
#       -> asset purchas programm provid suffici flexibl term adjust (2 fois | 7.7%)
#       -> govern council ecb decid previou meet corridor establish (1 fois | 3.8%)
#       -> first longer-term refinanc oper announc januari settl januari (1 fois | 3.8%)
#       -> real three-month interest rate measur nomin rate correct (1 fois | 3.8%)
#       -> nomin effect exchang rate euro area earli march (1 fois | 3.8%)
#       -> juli decid close target decemb order smooth transit (1 fois | 3.8%)
#       -> role refer valu within eurosystem 's monetari polici (1 fois | 3.8%)
#
# Mot : 'BOTTLENECK' (Total: 26)
#    Contexte : bottleneck ...
#       -> trigger upward pressur price rel earli stage econom (1 fois | 3.8%)
#       -> shortag labour market medium term remain paramount wage (1 fois | 3.8%)
#       -> could pose headwind industri activ near term indic (1 fois | 3.8%)
#       -> hold back product near term reopen larg part (1 fois | 3.8%)
#       -> last longer feed higher anticip wage rise price (1 fois | 3.8%)
#       -> rise energi price main risk pace recoveri outlook (1 fois | 3.8%)
#       -> feed higher anticip wage rise economi return quickli (1 fois | 3.8%)
#
# Mot : 'UNJUSTIFI' (Total: 26)
#    Contexte : unjustifi ...
#       -> war ukrain tragic conflict middl east major sourc (5 fois | 19.2%)
#       -> war ukrain tragic conflict middl east remain major (4 fois | 15.4%)
#       -> war ukrain peopl continu signific downsid risk economi (2 fois | 7.7%)
#       -> war ukrain increas broader geopolit tension could fragment (2 fois | 7.7%)
#       -> war ukrain tragic conflict middl east key sourc (2 fois | 7.7%)
#       -> war ukrain tragic conflict middl east could disrupt (2 fois | 7.7%)
#       -> war ukrain tighter financ condit worsen term trade (1 fois | 3.8%)
#
# Mot : 'CONFLICT' (Total: 25)
#    Contexte : conflict ...
#       -> middl east major sourc geopolit risk may result (5 fois | 20.0%)
#       -> middl east key sourc geopolit risk may result (2 fois | 8.0%)
#       -> middl east remain major sourc uncertainti contrast trade (2 fois | 8.0%)
#       -> may neg impact econom sentiment number countri end (1 fois | 4.0%)
#       -> iraq comprehens review monetari financi econom develop discuss (1 fois | 4.0%)
#       -> baselin scenario continu one moder recoveri associ diminish (1 fois | 4.0%)
#       -> best mix accordingli econom growth first half like (1 fois | 4.0%)
#
# Mot : 'IMPER' (Total: 25)
#    Contexte : imper ...
#       -> ensur medium longer-term inflat expect remain firmli anchor (5 fois | 20.0%)
#       -> parti concern meet respons second-round effect wage price-set (2 fois | 8.0%)
#       -> avoid broad-bas second-round effect price wage-set parti concern (2 fois | 8.0%)
#       -> progress toward capit market union complet bank union (2 fois | 8.0%)
#       -> monetari polici medium-term upward pressur price contain risk (1 fois | 4.0%)
#       -> budget prioritis consolid necessari moreov vital import reliabl (1 fois | 4.0%)
#       -> govern compli provis stabil growth pact fiscal consolid (1 fois | 4.0%)
#
# Mot : 'UNFAVOUR' (Total: 24)
#    Contexte : unfavour ...
#       -> effect energi price strong upward impact annual hicp (2 fois | 8.3%)
#       -> effect financ condit like dampen pace econom growth (2 fois | 8.3%)
#       -> effect financ condit confid ongo tension financi market (2 fois | 8.3%)
#       -> effect overal financ condit confid result ongo tension (2 fois | 8.3%)
#       -> price shock occur upward pressur soon start diminish (1 fois | 4.2%)
#       -> price shock inflat rate fall develop expect take (1 fois | 4.2%)
#       -> shock occur like annual rate inflat start fall (1 fois | 4.2%)
#
# Mot : 'SHARPLI' (Total: 23)
#    Contexte : sharpli ...
#       -> short-term volatil howev relev monetari polici perspect look (2 fois | 8.7%)
#       -> upward trend labour cost indic observ recent year (1 fois | 4.3%)
#       -> move unwelcom undesir econom growth turn price annual (1 fois | 4.3%)
#       -> move unwelcom undesir econom growth turn consum price (1 fois | 4.3%)
#       -> move unwelcom undesir econom growth domest side uncertainti (1 fois | 4.3%)
#       -> novemb octob oil price risen strongli recent month (1 fois | 4.3%)
#       -> rise fiscal imbal address clear credibl exit strategi (1 fois | 4.3%)
#
# Mot : 'CRITIC' (Total: 22)
#    Contexte : critic ...
#       -> safeguard sound fiscal posit likewis transpar consist implement (4 fois | 18.2%)
#       -> view sharp contract euro area economi measur taken (3 fois | 13.6%)
#       -> view sharp contract euro area economi fiscal measur (2 fois | 9.1%)
#       -> time support firm household expos ongo pandem associ (2 fois | 9.1%)
#       -> point credibl institut underpin emu must maintain treati (1 fois | 4.5%)
#       -> issu need better implement commit alreadi made end (1 fois | 4.5%)
#       -> face tripl challeng acceler globalis rapid technolog chang (1 fois | 4.5%)
#
# Mot : 'DRAG' (Total: 21)
#    Contexte : drag ...
#       -> invest consumpt deterior financi market sentiment could lead (4 fois | 19.0%)
#       -> euro area growth world economi weaken sharpli expect (2 fois | 9.5%)
#       -> activ time come account ongo process balanc sheet (1 fois | 4.8%)
#       -> euro area growth momentum howev ongo albeit deceler (1 fois | 4.8%)
#       -> consumpt invest pace suppli bottleneck resolv risk outlook (1 fois | 4.8%)
#       -> trade sentiment inflat could consider higher near term (1 fois | 4.8%)
#       -> demand expect constrain consumpt invest factor risk outlook (1 fois | 4.8%)
#
# Mot : 'AVERS' (Total: 20)
#    Contexte : avers ...
#       -> ongo adjust balanc sheet household enterpris weigh credit (6 fois | 30.0%)
#       -> make firm household less will invest consum geopolit (3 fois | 15.0%)
#       -> financi market would weigh domest demand would therebi (3 fois | 15.0%)
#       -> weaker growth geopolit tension particular russia unjustifi war (2 fois | 10.0%)
#       -> correspond weak privat long-term capit flow real invest (1 fois | 5.0%)
#       -> background ongo geopolit tension turbul oil market could (1 fois | 5.0%)
#       -> household firm given stock market loss experienc spring (1 fois | 5.0%)
#
# Mot : 'SUFFER' (Total: 20)
#    Contexte : suffer ...
#       -> high fiscal extern deficit remov labour market rigid (4 fois | 20.0%)
#       -> high fiscal extern deficit measur ensur wage bargain (3 fois | 15.0%)
#       -> major imbal dampen global slowdown invest growth provid (1 fois | 5.0%)
#       -> major imbal look ahead domest foreign demand expect (1 fois | 5.0%)
#       -> major imbal line avail forecast domest foreign demand (1 fois | 5.0%)
#       -> major imbal background expect invest growth euro area (1 fois | 5.0%)
#       -> major imbal context invest growth euro area continu (1 fois | 5.0%)
#
# Mot : 'DISTORT' (Total: 19)
#    Contexte : distort ...
#       -> upward non-euro area resid ' purchas negoti paper (1 fois | 5.3%)
#       -> becom sizeabl recent month current amount around half (1 fois | 5.3%)
#       -> annual growth result non-euro area resid ' hold (1 fois | 5.3%)
#       -> well inform first pillar conclud longer risk price (1 fois | 5.3%)
#       -> upward hold money market paper short-term debt secur (1 fois | 5.3%)
#       -> necessari adjust process moreov degre competit euro area (1 fois | 5.3%)
#       -> progress increas competit sector would highli benefici turn (1 fois | 5.3%)
#
# Mot : 'TRAGIC' (Total: 19)
#    Contexte : tragic ...
#       -> conflict middl east major sourc geopolit risk may (5 fois | 26.3%)
#       -> conflict middl east remain major sourc uncertainti contrast (3 fois | 15.8%)
#       -> conflict middl east key sourc geopolit risk may (2 fois | 10.5%)
#       -> event unit state current activ combat global terror (1 fois | 5.3%)
#       -> event madrid march suggest major impact confid continu (1 fois | 5.3%)
#       -> event lament loss life thought suffer directli indirectli (1 fois | 5.3%)
#       -> conflict trigger terrorist attack israel key sourc geopolit (1 fois | 5.3%)
#
# Mot : 'UNDERMIN' (Total: 17)
#    Contexte : undermin ...
#       -> stabil growth pact key pillar econom monetari union (2 fois | 11.8%)
#       -> addit exchang rate trend need monitor close given (1 fois | 5.9%)
#       -> credibl consolid process effort set condit expand product (1 fois | 5.9%)
#       -> principl budgetari disciplin let possibl automat stabilis oper (1 fois | 5.9%)
#       -> persist imbal relat particular sustain public financ extern (1 fois | 5.9%)
#       -> credibl institut framework confid sound public financ member (1 fois | 5.9%)
#       -> extern imbal part world economi concern price latest (1 fois | 5.9%)
#
# Mot : 'CAUTION' (Total: 17)
#    Contexte : caution ...
#       -> therefor exercis interpret recent develop real gdp growth (1 fois | 5.9%)
#       -> concern financi market indic upturn long-term interest rate (1 fois | 5.9%)
#       -> requir interpret short-term monetari develop note -month growth (1 fois | 5.9%)
#       -> continu warrant regard upsid risk price stabil stem (1 fois | 5.9%)
#       -> still need exercis howev given continu dynam credit (1 fois | 5.9%)
#       -> therefor warrant assess like impact hicp inflat short (1 fois | 5.9%)
#       -> respect crucial social partner continu process wage moder (1 fois | 5.9%)
#
# Mot : 'DETRIMENT' (Total: 17)
#    Contexte : detriment ...
#       -> employ competit countri concern govern council therefor call (6 fois | 35.3%)
#       -> employ competit countri concern govern council call scheme (2 fois | 11.8%)
#       -> activ consequ sake transpar effici account govern council (1 fois | 5.9%)
#       -> financi interest commun ecb find inform relat decis (1 fois | 5.9%)
#       -> current favour growth prospect sinc monetari polici would (1 fois | 5.9%)
#       -> return sustain econom growth adher medium-term object strengthen (1 fois | 5.9%)
#       -> effect economi well geopolit tension reflect surg oil (1 fois | 5.9%)
#
# Mot : 'SHORTAG' (Total: 17)
#    Contexte : shortag ...
#       -> labour market medium term remain paramount wage develop (1 fois | 5.9%)
#       -> bank system oper provid effect backstop case need (1 fois | 5.9%)
#       -> turn persist hold back product financi monetari condit (1 fois | 5.9%)
#       -> materi equip spread delta variant far requir lockdown (1 fois | 5.9%)
#       -> materi equip cours factor eas fall year-on-year inflat (1 fois | 5.9%)
#       -> turn persist current expect hold back product financi (1 fois | 5.9%)
#       -> materi equip labour hold back product sector inflat (1 fois | 5.9%)
#
# Mot : 'EXPLOIT' (Total: 16)
#    Contexte : exploit ...
#       -> make faster progress fiscal consolid urgent implement far-reach (2 fois | 12.5%)
#       -> respons polici area urg even take necessari step (1 fois | 6.2%)
#       -> favour interest rate condit financ consumpt invest plan (1 fois | 6.2%)
#       -> growth employ potenti decis structur measur field econom (1 fois | 6.2%)
#       -> potenti ultim increas per capita incom enhanc employ (1 fois | 6.2%)
#       -> current potenti costli would also make increasingli difficult (1 fois | 6.2%)
#       -> opportun singl market help safeguard prosper citizen europ (1 fois | 6.2%)
#
# Mot : 'DIFFICULT' (Total: 16)
#    Contexte : difficult ...
#       -> advanc area environ weaker econom activ need properli (1 fois | 6.2%)
#       -> quantifi size establish time effect price stabil maintain (1 fois | 6.2%)
#       -> offer precis assess time strength econom upsw euro (1 fois | 6.2%)
#       -> reach object set lisbon agenda structur reform take (1 fois | 6.2%)
#       -> junctur predict time strength econom upsw euro area (1 fois | 6.2%)
#       -> anticip particularli due volatil oil price increas annual (1 fois | 6.2%)
#       -> stage like outcom remain inflat stabilis cours level (1 fois | 6.2%)
#
# Mot : 'SLOWLI' (Total: 16)
#    Contexte : slowli ...
#       -> regard second pillar expect rebound real gdp growth (1 fois | 6.2%)
#       -> recent month explain still cautiou realloc portfolio econom (1 fois | 6.2%)
#       -> time growth loan privat sector edg monetari credit (1 fois | 6.2%)
#       -> sinc summer evid continu portfolio shift longer-term asset (1 fois | 6.2%)
#       -> would expect basi histor regular may reflect increas (1 fois | 6.2%)
#       -> other sever countri fiscal perspect worri imbal project (1 fois | 6.2%)
#       -> anticip thu far assess also broadli reflect septemb (1 fois | 6.2%)
#
# Mot : 'ESCAL' (Total: 16)
#    Contexte : escal ...
#       -> trade tension major economi would weigh euro area (4 fois | 25.0%)
#       -> export support recoveri global demand rise fiscal structur (2 fois | 12.5%)
#       -> wage moder prevail respect nomin wage growth alreadi (1 fois | 6.2%)
#       -> tension middl east result expect modest rate econom (1 fois | 6.2%)
#       -> fiscal structur polici make economi product competit resili (1 fois | 6.2%)
#       -> trade tension would lower euro area growth dampen (1 fois | 6.2%)
#       -> trade tension could see euro depreci import cost (1 fois | 6.2%)
#
# Mot : 'INCONSIST' (Total: 16)
#    Contexte : inconsist ...
#       -> progress toward sustain adjust path inflat stand readi (9 fois | 56.2%)
#       -> counter downward impact pandem project path inflat addit (5 fois | 31.2%)
#       -> progress toward sustain adjust path inflat govern council (1 fois | 6.2%)
#       -> progress toward two per cent target stand readi (1 fois | 6.2%)
#
# Mot : 'BURDEN' (Total: 15)
#    Contexte : burden ...
#       -> monetari polici undermin stabil growth pact key pillar (2 fois | 13.3%)
#       -> improv fiscal expenditur structur labour market flexibl competit (1 fois | 6.7%)
#       -> loss within economi risk endang continu non-inflationari growth (1 fois | 6.7%)
#       -> corpor household without threaten slow progress fiscal consolid (1 fois | 6.7%)
#       -> result higher oil price avoid medium-term impact limit (1 fois | 6.7%)
#       -> shift younger futur gener consider challeng therefor remain (1 fois | 6.7%)
#       -> stimul technolog innov exploit complementari natur reform would (1 fois | 6.7%)
#
# Mot : 'DOWNTURN' (Total: 15)
#    Contexte : downturn ...
#       -> accordingli extern domest inflationari pressur diminish continu expect (2 fois | 13.3%)
#       -> global euro area demand like remain weak gradual (2 fois | 13.3%)
#       -> prospect extern domest demand remain weak gradual recov (2 fois | 13.3%)
#       -> addit revenu shortfal fiscal stimulu measur adopt mani (1 fois | 6.7%)
#       -> econom activ inde recent econom data releas survey (1 fois | 6.7%)
#       -> euro area countri updat stabil programm recent addenda (1 fois | 6.7%)
#       -> world economi avail data survey indic suggest econom (1 fois | 6.7%)
#
# Mot : 'UNEXPECT' (Total: 14)
#    Contexte : unexpect ...
#       -> oil price rise monetari analysi confirm prevail upsid (2 fois | 14.3%)
#       -> declin commod price stronger expect slowdown economi could (2 fois | 14.3%)
#       -> develop energi price past declin euro order maintain (1 fois | 7.1%)
#       -> extra revenu deficit debt reduct countri remain fiscal (1 fois | 7.1%)
#       -> rise indirect tax administ price background imper ensur (1 fois | 7.1%)
#       -> rise indirect tax administ price could occur background (1 fois | 7.1%)
#       -> increas commod price well indirect tax administ price (1 fois | 7.1%)
#
# Mot : 'HALT' (Total: 13)
#    Contexte : halt ...
#       -> revers increas govern debt ratio moreov countri must (2 fois | 15.4%)
#       -> addit recent develop econom financi indic emerg market (1 fois | 7.7%)
#       -> recent vein note inertia consum price develop euro (1 fois | 7.7%)
#       -> wage moder crucial maintain price stabil furthermor would (1 fois | 7.7%)
#       -> howev indic still mix despit weak econom activ (1 fois | 7.7%)
#       -> summer month shorter-term dynam strengthen reflect fact histor (1 fois | 7.7%)
#       -> recent month shorter-term dynam strengthen annual growth rate (1 fois | 7.7%)
#
# Mot : 'DISAPPEAR' (Total: 13)
#    Contexte : disappear ...
#       -> still strong underli pace monetari expans point upsid (2 fois | 15.4%)
#       -> complet junctur therefor crucial parti includ public author (2 fois | 15.4%)
#       -> order encourag develop cross-bord payment system enabl public (1 fois | 7.7%)
#       -> instead monetari develop togeth accumul evid improv econom (1 fois | 7.7%)
#       -> time market open januari long-term govern bond yield (1 fois | 7.7%)
#       -> gradual hicp rate inflat increasingli depend domest forc (1 fois | 7.7%)
#       -> start extern environ euro area forecast world growth (1 fois | 7.7%)
#
# Mot : 'UNDU' (Total: 13)
#    Contexte : undu ...
#       -> delay monetari polici focus maintain price stabil medium (8 fois | 61.5%)
#       -> delay order reap full benefit monetari polici measur (2 fois | 15.4%)
#       -> caus concern howev term outlook price stabil medium (1 fois | 7.7%)
#       -> constraint credit suppli compani household combin recent broad-bas (1 fois | 7.7%)
#       -> delay govern council continu monitor close evolut outlook (1 fois | 7.7%)
#
# Mot : 'INTENT' (Total: 12)
#    Contexte : intent ...
#       -> particular technic assumpt short-term interest rate taken market (2 fois | 16.7%)
#       -> termin transit measur follow next meet govern council (1 fois | 8.3%)
#       -> maintain level forese futur first oper eurosystem success (1 fois | 8.3%)
#       -> maintain rate forese futur like inform govern council (1 fois | 8.3%)
#       -> non-particip eu central bank background set monetari polici (1 fois | 8.3%)
#       -> govern council meet held euro area member state (1 fois | 8.3%)
#       -> reflect latest round stabil programm impli rise euro (1 fois | 8.3%)
#
# Mot : 'OVERCOM' (Total: 12)
#    Contexte : overcom ...
#       -> credit suppli constraint sum cross-check outcom econom analysi (2 fois | 16.7%)
#       -> econom agent see - name one-off temporari price (1 fois | 8.3%)
#       -> inertia implement structur reform within area fiscal expenditur (1 fois | 8.3%)
#       -> structur ineffici function market must step would promot (1 fois | 8.3%)
#       -> obstacl toward employ growth reduc trend structur level (1 fois | 8.3%)
#       -> compar low rate labour market particip still high (1 fois | 8.3%)
#       -> current crisi rapidli success complet doha round trade (1 fois | 8.3%)
#
# Mot : 'TURBUL' (Total: 12)
#    Contexte : turbul ...
#       -> sinc earli august strongli influenc dynam broad money (3 fois | 25.0%)
#       -> expect improv econom activ euro area conting recoveri (1 fois | 8.3%)
#       -> oil market could neg impact econom activ throughout (1 fois | 8.3%)
#       -> sinc earli august strongli influenc overal dynam broad (1 fois | 8.3%)
#       -> could last longer initi thought could broader current (1 fois | 8.3%)
#       -> seen sinc earli august strongli influenc overal dynam (1 fois | 8.3%)
#       -> neg impact real economi previous anticip moreov downsid (1 fois | 8.3%)
#
# Mot : 'FEAR' (Total: 12)
#    Contexte : fear ...
#       -> rise protectionist pressur possibl increas oil price concern (4 fois | 33.3%)
#       -> rise protectionist pressur especi suspens doha round trade (3 fois | 25.0%)
#       -> rise protectionist pressur possibl renew increas oil price (2 fois | 16.7%)
#       -> rise protectionist pressur concern possibl disorderli develop owe (1 fois | 8.3%)
#       -> revers euro unaccept need address fundament manner euro (1 fois | 8.3%)
#       -> part investor revers euro henc appropri condit fulli (1 fois | 8.3%)
#
# Mot : 'OVERST' (Total: 12)
#    Contexte : overst ...
#       -> underli pace monetari expans nonetheless even take effect (2 fois | 16.7%)
#       -> may also influenc temporari factor seri strong monetari (1 fois | 8.3%)
#       -> inde strong growth privat sector credit reflect continu (1 fois | 8.3%)
#       -> underli rate money credit expans broad assess underli (1 fois | 8.3%)
#       -> pace underli monetari expans rel flat yield curv (1 fois | 8.3%)
#       -> pace underli monetari expans howev even take effect (1 fois | 8.3%)
#       -> underli pace monetari expans owe impact flat yield (1 fois | 8.3%)
#
# Mot : 'HAMPER' (Total: 11)
#    Contexte : hamper ...
#       -> develop effici function euro area money market therefor (1 fois | 9.1%)
#       -> recoveri confid therefor govern council welcom recent commun (1 fois | 9.1%)
#       -> adjust process jean-claud trichet presid ecb luca papademo (1 fois | 9.1%)
#       -> euro area still data analysi need firmli assess (1 fois | 9.1%)
#       -> weak labour market prospect govern council continu view (1 fois | 9.1%)
#       -> recoveri sum econom analysi confirm expect prolong period (1 fois | 9.1%)
#       -> recoveri time policy-mak euro area push ahead area (1 fois | 9.1%)
#
# Mot : 'DEVIAT' (Total: 11)
#    Contexte : deviat ...
#       -> refer valu steadili increas strong growth liquid compon (1 fois | 9.1%)
#       -> growth refer valu throughout well ongo strong expans (1 fois | 9.1%)
#       -> growth refer valu especi seen conjunct dynam growth (1 fois | 9.1%)
#       -> refer valu growth rate increas earli pictur gener (1 fois | 9.1%)
#       -> growth refer valu combin strong growth credit privat (1 fois | 9.1%)
#       -> upsid refer valu pronounc expans credit privat sector (1 fois | 9.1%)
#       -> growth refer valu sinc start stage three emu (1 fois | 9.1%)
#
# Mot : 'ABSENC' (Total: 11)
#    Contexte : absenc ...
#       -> unfavour price shock inflat rate fall develop expect (1 fois | 9.1%)
#       -> unfavour shock like price stabil restor distant futur (1 fois | 9.1%)
#       -> shock food price addit crucial medium term two (1 fois | 9.1%)
#       -> major imbal turn price develop let first recal (1 fois | 9.1%)
#       -> major imbal support posit outlook euro area economi (1 fois | 9.1%)
#       -> major imbal within euro area overal suggest real (1 fois | 9.1%)
#       -> exchang rate uncertainti within euro area low long-term (1 fois | 9.1%)
#
# Mot : 'CONCEAL' (Total: 11)
#    Contexte : conceal ...
#       -> return posit annual rate growth case loan household (1 fois | 9.1%)
#       -> ongo opposit develop posit strengthen annual growth loan (1 fois | 9.1%)
#       -> countervail develop posit strengthen annual growth loan household (1 fois | 9.1%)
#       -> posit monthli flow also conceal ongo opposit develop (1 fois | 9.1%)
#       -> ongo opposit develop sector level posit increas annual (1 fois | 9.1%)
#       -> fact monthli flow posit number month time aggreg (1 fois | 9.1%)
#       -> countervail develop posit growth loan household neg growth (1 fois | 9.1%)
#
# Mot : 'UNEXPECTEDLI' (Total: 11)
#    Contexte : unexpectedli ...
#       -> financi monetari condit market interest rate risen sinc (2 fois | 18.2%)
#       -> greater friction global trade would make euro area (2 fois | 18.2%)
#       -> high energi cost price rise also becom broadli (1 fois | 9.1%)
#       -> potenti owe part recent rise geopolit risk financi (1 fois | 9.1%)
#       -> moreov inflat could declin quickli near term energi (1 fois | 9.1%)
#       -> financi monetari condit market interest rate broadli stabl (1 fois | 9.1%)
#       -> financi monetari condit polici rate cut june transmit (1 fois | 9.1%)
#
# Mot : 'PROBLEM' (Total: 10)
#    Contexte : problem ...
#       -> well domest extern imbal need urgent address countri (2 fois | 20.0%)
#       -> experienc initi period regard teeth troubl complet normal (1 fois | 10.0%)
#       -> transit year includ provis suffici liquid money market (1 fois | 10.0%)
#       -> associ risk premium short-term interest rate alreadi declin (1 fois | 10.0%)
#       -> countri aris fact countri take opportun improv substanti (1 fois | 10.0%)
#       -> euro area name high level structur unemploy dispos (1 fois | 10.0%)
#       -> euro area name high level structur unemploy time (1 fois | 10.0%)
#
# Mot : 'REASSESS' (Total: 9)
#    Contexte : reassess ...
#       -> may appropri money credit growth increas turn financi (1 fois | 11.1%)
#       -> respect whether signal risk price stabil regard second (1 fois | 11.1%)
#       -> monetari develop especi evid recoveri euro area economi (1 fois | 11.1%)
#       -> monetari stimulu achiev expans balanc sheet outlook price (1 fois | 11.1%)
#       -> outlook price develop monetari stimulu achiev result govern (1 fois | 11.1%)
#       -> underli macroeconom condit like path inflat growth distribut (1 fois | 11.1%)
#       -> econom outlook balanc risk basi updat assess govern (1 fois | 11.1%)

# %%
from collections import Counter

# On définit la taille de la fenêtre ici (8 mots)
N_FOLLOWERS = 8

try:
    texts = df['clean_text']
    full_text = " ".join(texts).lower().split()

    # --- CORRECTION ICI ---
    # On arrête la boucle N_FOLLOWERS avant la fin pour éviter le crash
    limit = len(full_text) - N_FOLLOWERS

    top_positives = pos_counter.most_common(100)

    print(f"--- ANALYSE DE CONTEXTE SUR LE TOP 50 POSITIF ({N_FOLLOWERS} mots suivants) ---")

    for word_tuple in top_positives:
        target_word = word_tuple[0]
        freq_global = word_tuple[1]

        followers = []

        # On boucle seulement jusqu'à la limite sécurisée
        for i in range(limit):
            if full_text[i] == target_word:
                # On capture les N mots suivants proprement
                # Slice: de i+1 jusqu'à i+1+N
                ngram_list = full_text[i+1 : i+1+N_FOLLOWERS]
                ngram = " ".join(ngram_list)
                followers.append(ngram)

        common_followers = Counter(followers).most_common(7)

        if common_followers:
            print(f"\nMot : '{target_word.upper()}' (Total: {freq_global})")
            print(f"   Contexte : {target_word} ...")
            for next_word, count in common_followers:
                pct = (count / len(followers)) * 100 if len(followers) > 0 else 0
                print(f"      -> {next_word} ({count} fois | {pct:.1f}%)")

except Exception as e:
    print(f"Erreur : {e}")
# Out:
# --- ANALYSE DE CONTEXTE SUR LE TOP 50 POSITIF (8 mots suivants) ---
#
# Mot : 'STABIL' (Total: 1298)
#    Contexte : stabil ...
#       -> maintain medium term therebi support purchas power euro (38 fois | 2.9%)
#       -> medium term cross-check signal monetari analysi confirm pictur (20 fois | 1.5%)
#       -> growth pact macroeconom imbal procedur time across countri (12 fois | 0.9%)
#       -> accordingli continu monitor close develop period ahead regard (11 fois | 0.8%)
#       -> medium term accommod stanc contribut support econom activ (9 fois | 0.7%)
#       -> anchor prerequisit monetari polici make ongo contribut toward (8 fois | 0.6%)
#       -> medium longer term monetari develop therefor continu requir (8 fois | 0.6%)
#
# Mot : 'IMPROV' (Total: 576)
#    Contexte : improv ...
#       -> function econom monetari union remain prioriti govern council (15 fois | 2.6%)
#       -> busi environ includ provis adequ public infrastructur vital (10 fois | 1.7%)
#       -> fund situat bank order ensur adequ transmiss monetari (7 fois | 1.2%)
#       -> busi environ firm need gain momentum sever countri (7 fois | 1.2%)
#       -> qualiti effici public servic minimis distortionari effect taxat (6 fois | 1.0%)
#       -> domest demand support accommod monetari polici stanc euro (5 fois | 0.9%)
#       -> financi condit progress made fiscal consolid structur reform (5 fois | 0.9%)
#
# Mot : 'STRONG' (Total: 502)
#    Contexte : strong ...
#       -> properti market develop mani part euro area sum (8 fois | 1.6%)
#       -> busi confid could provid support domest econom activ (5 fois | 1.0%)
#       -> monetari credit growth environ ampl liquid point upsid (4 fois | 0.8%)
#       -> determin keep medium long-term inflat expect firmli anchor (4 fois | 0.8%)
#       -> benefit extend period favour financ condit balanc sheet (3 fois | 0.6%)
#       -> earn gain busi effici consumpt growth euro area (3 fois | 0.6%)
#       -> momentum invest remain dynam benefit extend period favour (3 fois | 0.6%)
#
# Mot : 'INFORM' (Total: 472)
#    Contexte : inform ...
#       -> becom avail sinc last meet underpin reason behind (6 fois | 1.3%)
#       -> avail current oil futur price annual hicp inflat (6 fois | 1.3%)
#       -> becom avail sinc confirm assess adjust accommod monetari (5 fois | 1.1%)
#       -> econom monetari develop assess impact outlook price stabil (5 fois | 1.1%)
#       -> provid two pillar ecb 's monetari polici strategi (4 fois | 0.8%)
#       -> also confirm econom recoveri euro area continu earli (4 fois | 0.8%)
#       -> also confirm econom recoveri euro area continu first (4 fois | 0.8%)
#
# Mot : 'STRENGTHEN' (Total: 445)
#    Contexte : strengthen ...
#       -> capit base take full advantag govern support measur (15 fois | 3.4%)
#       -> broaden amid high level capac utilis tighten labour (10 fois | 2.2%)
#       -> bank resili shock ensur adequ access financ therebi (9 fois | 2.0%)
#       -> time line develop real dispos incom employ condit (7 fois | 1.6%)
#       -> capit base necessari take full advantag govern support (7 fois | 1.6%)
#       -> capit base necessari take full advantag govern measur (6 fois | 1.3%)
#       -> longer-term growth potenti reduc vulner implement structur reform (5 fois | 1.1%)
#
# Mot : 'CONFID' (Total: 426)
#    Contexte : confid ...
#       -> fiscal framework time countri strive growth-friendli composit fiscal (9 fois | 2.1%)
#       -> could provid support domest econom activ euro area (7 fois | 1.6%)
#       -> euro area privat sector domest demand increasingli contribut (4 fois | 0.9%)
#       -> therebi delay recoveri accord eurostat flash estim euro (4 fois | 0.9%)
#       -> survey indicator-bas estim support assess robust econom growth (3 fois | 0.7%)
#       -> may also improv quickli labour market deterior may (3 fois | 0.7%)
#       -> essenti govern reduc fiscal structur imbal proceed financi (3 fois | 0.7%)
#
# Mot : 'POSIT' (Total: 398)
#    Contexte : posit ...
#       -> reflect part continu interest intern investor euro area (5 fois | 1.3%)
#       -> object environ accommod monetari polici swift effect implement (5 fois | 1.3%)
#       -> come month remain moder posit rate policy-relev horizon (4 fois | 1.0%)
#       -> fiscal develop may emerg reflect factor favour expect (4 fois | 1.0%)
#       -> underli momentum econom activ euro area uncertainti remain (4 fois | 1.0%)
#       -> uncertainti remain elev continu monitor close develop respect (4 fois | 1.0%)
#       -> likewis transpar consist implement eu fiscal econom govern (4 fois | 1.0%)
#
# Mot : 'STRONGER' (Total: 286)
#    Contexte : stronger ...
#       -> current expect owe need fiscal consolid come year (9 fois | 3.1%)
#       -> anticip effect stem extens macroeconom stimulu provid polici (8 fois | 2.8%)
#       -> protract expect neg feedback loop real economi financi (7 fois | 2.4%)
#       -> pass-through past oil price rise consum price current (6 fois | 2.1%)
#       -> expect increas administ price indirect tax well higher (6 fois | 2.1%)
#       -> expect increas administ price indirect tax downsid risk (5 fois | 1.7%)
#       -> uniform recoveri would increas econom resili growth potenti (4 fois | 1.4%)
#
# Mot : 'BENEFIT' (Total: 259)
#    Contexte : benefit ...
#       -> monetari polici measur polici area must contribut decis (29 fois | 11.2%)
#       -> extend period favour financ condit balanc sheet restructur (13 fois | 5.0%)
#       -> monetari polici measur polici area must contribut much (10 fois | 3.9%)
#       -> intensifi effort toward achiev growth-friendli composit public financ (10 fois | 3.9%)
#       -> low domest price pressur inflat expect medium longer (4 fois | 1.5%)
#       -> accommod monetari polici stanc measur adopt improv function (3 fois | 1.2%)
#       -> gradual strengthen demand export furthermor overal improv financi (3 fois | 1.2%)
#
# Mot : 'PROGRESS' (Total: 228)
#    Contexte : progress ...
#       -> toward sustain adjust path inflat stand readi increas (9 fois | 3.9%)
#       -> made improv fund situat bank order ensur adequ (7 fois | 3.1%)
#       -> made fiscal consolid addit real incom benefit recent (5 fois | 2.2%)
#       -> capit market union reform improv resolut non-perform loan (5 fois | 2.2%)
#       -> feed economi full henc measur taken monetari polici (4 fois | 1.8%)
#       -> made improv fund situat bank particular strengthen domest (4 fois | 1.8%)
#       -> made sinc last summer improv fund situat bank (3 fois | 1.3%)
#
# Mot : 'ENHANC' (Total: 197)
#    Contexte : enhanc ...
#       -> credit support secur market programm fulli consist mandat (4 fois | 2.0%)
#       -> wage flexibl incent work remov labour market rigid (4 fois | 2.0%)
#       -> current invest initi includ extens juncker plan progress (4 fois | 2.0%)
#       -> forward guidanc key ecb interest rate event govern (4 fois | 2.0%)
#       -> euro area suppli capac would support full implement (4 fois | 2.0%)
#       -> competit innov urgent need speed restructur invest creat (3 fois | 1.5%)
#       -> credit support bank system take account ongo improv (3 fois | 1.5%)
#
# Mot : 'ACHIEV' (Total: 154)
#    Contexte : achiev ...
#       -> growth-friendli composit public financ full transpar consist implement (10 fois | 6.5%)
#       -> growth-friendli composit public financ likewis transpar consist implement (8 fois | 5.2%)
#       -> aim continu follow data-depend meeting-by-meet approach determin appropri (8 fois | 5.2%)
#       -> time return inflat two per cent medium-term target (6 fois | 3.9%)
#       -> object govern council remain strongli commit prevent second-round (5 fois | 3.2%)
#       -> object continu monitor close develop period ahead allow (3 fois | 1.9%)
#       -> object continu monitor close develop period ahead regard (3 fois | 1.9%)
#
# Mot : 'PLEAS' (Total: 153)
#    Contexte : pleas ...
#       -> welcom press confer report outcom today meet govern (76 fois | 49.7%)
#       -> welcom today press confer let report outcom meet (8 fois | 5.2%)
#       -> welcom today press confer report outcom today meet (7 fois | 4.6%)
#       -> welcom press confer report outcom today meet base (6 fois | 3.9%)
#       -> welcom press confer let wish happi new year (5 fois | 3.3%)
#       -> welcom press confer report outcom today meet also (4 fois | 2.6%)
#       -> welcom first press confer let therefor wish happi (3 fois | 2.0%)
#
# Mot : 'GOOD' (Total: 150)
#    Contexte : good ...
#       -> afternoon vice-presid welcom press confer govern council today (17 fois | 11.3%)
#       -> afternoon vice-presid welcom press confer would like thank (3 fois | 2.0%)
#       -> afternoon vice-presid welcom press confer euro area economi (2 fois | 1.3%)
#       -> servic quickli current anticip financi monetari condit monetari (2 fois | 1.3%)
#       -> afternoon vice-presid welcom press confer inflat continu declin (2 fois | 1.3%)
#       -> inflat unchang per cent indic underli inflat remain (2 fois | 1.3%)
#       -> sector particularli sensit deterior extern environ howev time (1 fois | 0.7%)
#
# Mot : 'LEAD' (Total: 150)
#    Contexte : lead ...
#       -> wage-pric spiral would detriment employ competit countri concern (8 fois | 5.3%)
#       -> higher sustain econom growth euro area also rais (6 fois | 4.0%)
#       -> higher sustain econom growth euro area also make (6 fois | 4.0%)
#       -> broad-bas inflationari pressur inflat expect must remain firmli (4 fois | 2.7%)
#       -> sustain return inflat rate toward level close medium (4 fois | 2.7%)
#       -> inflationari pressur harm purchas power euro area citizen (3 fois | 2.0%)
#       -> greater volatil risk avers financi market would weigh (3 fois | 2.0%)
#
# Mot : 'STRENGTH' (Total: 134)
#    Contexte : strength ...
#       -> monetari polici transmiss pre-commit particular rate path case (13 fois | 9.7%)
#       -> monetari polici transmiss pre-commit particular rate path decis (12 fois | 9.0%)
#       -> monetari polici transmiss determin ensur inflat stabilis sustain (5 fois | 3.7%)
#       -> monetari polici transmiss decis taken today set press (4 fois | 3.0%)
#       -> monetari credit expans euro area past year creat (3 fois | 2.2%)
#       -> monetari polici transmiss case stand readi adjust instrument (3 fois | 2.2%)
#       -> monetari polici transmiss disinfl process well track inflat (3 fois | 2.2%)
#
# Mot : 'PROFIT' (Total: 115)
#    Contexte : profit ...
#       -> increas expect upsid risk inflat also stem heighten (6 fois | 5.2%)
#       -> margin could also drive inflat higher includ medium (5 fois | 4.3%)
#       -> therefor privat consumpt invest furthermor demand euro area (3 fois | 2.6%)
#       -> margin prove resili contrast inflat may surpris downsid (3 fois | 2.6%)
#       -> low level interest rate gener favour financ condit (2 fois | 1.7%)
#       -> sustain employ growth robust unemploy rate fallen level (2 fois | 1.7%)
#       -> margin wage measur accompani structur reform increas competit (2 fois | 1.7%)
#
# Mot : 'OPPORTUN' (Total: 102)
#    Contexte : opportun ...
#       -> cost hold liquid deposit accordingli narrow monetari aggreg (5 fois | 4.9%)
#       -> cost hold narrow monetari aggreg continu main contributor (4 fois | 3.9%)
#       -> cost hold fund liquid compon includ continu grow (3 fois | 2.9%)
#       -> cost hold rel financi instrument narrow monetari aggreg (3 fois | 2.9%)
#       -> appropri restructur bank sector also play import role (2 fois | 2.0%)
#       -> cost hold liquid form money narrow monetari aggreg (2 fois | 2.0%)
#       -> recal real three-month interest rate measur nomin rate (1 fois | 1.0%)
#
# Mot : 'GAIN' (Total: 91)
#    Contexte : gain ...
#       -> busi effici consumpt also strengthen time line develop (5 fois | 5.5%)
#       -> earn busi effici consumpt growth also strengthen time (3 fois | 3.3%)
#       -> busi effici consumpt growth euro area also strengthen (3 fois | 3.3%)
#       -> also benefit past structur reform still rel low (3 fois | 3.3%)
#       -> turn partli reflect past labour market reform grow (3 fois | 3.3%)
#       -> conjunct rise wage mildli expansionari euro area fiscal (3 fois | 3.3%)
#       -> momentum past month growth monetari aggreg driven liquid (2 fois | 2.2%)
#
# Mot : 'BOOST' (Total: 87)
#    Contexte : boost ...
#       -> euro area product growth potenti regard fiscal polici (10 fois | 11.5%)
#       -> defenc infrastructur spend could also rais inflat medium (6 fois | 6.9%)
#       -> euro area product growth potenti reduc structur unemploy (5 fois | 5.7%)
#       -> job creation enhanc current invest initi includ extens (4 fois | 4.6%)
#       -> potenti output growth euro area structur reform necessari (4 fois | 4.6%)
#       -> job creation rais product growth polici area need (3 fois | 3.4%)
#       -> job creation rais product implement product labour market (3 fois | 3.4%)
#
# Mot : 'CONCLUS' (Total: 85)
#    Contexte : conclus ...
#       -> govern council today decid keep three key ecb (10 fois | 11.8%)
#       -> govern council today decid lower three key ecb (7 fois | 8.2%)
#       -> negoti european commiss liaison ecb intern monetari fund (3 fois | 3.5%)
#       -> take account latest evid avail govern council alter (2 fois | 2.4%)
#       -> monetari polici drawn consequ govern council monitor close (2 fois | 2.4%)
#       -> doha round world trade negoti also help improv (2 fois | 2.4%)
#       -> sum today rais three key ecb interest rate (2 fois | 2.4%)
#
# Mot : 'EFFICI' (Total: 81)
#    Contexte : effici ...
#       -> consumpt also strengthen time line develop real dispos (5 fois | 6.2%)
#       -> consumpt growth also strengthen time line develop real (3 fois | 3.7%)
#       -> consumpt growth euro area also strengthen time line (3 fois | 3.7%)
#       -> sum base regular econom monetari analys govern council (3 fois | 3.7%)
#       -> higher profit also support busi invest moreov privat (2 fois | 2.5%)
#       -> consumpt growth evolv broadli line expect develop dispos (2 fois | 2.5%)
#       -> consumpt growth gradual rise broadli line expect develop (2 fois | 2.5%)
#
# Mot : 'SMOOTH' (Total: 68)
#    Contexte : smooth ...
#       -> function monetari polici transmiss readi take christin lagard (22 fois | 32.8%)
#       -> transmiss monetari polici favour financ condit maintain asset (5 fois | 7.5%)
#       -> transmiss monetari polici conduct net asset purchas pepp (3 fois | 4.5%)
#       -> cash changeov find inform relat decis separ press (2 fois | 3.0%)
#       -> start system regard first experi oper exist let (1 fois | 1.5%)
#       -> transit escb institut also financi institut day thu (1 fois | 1.5%)
#       -> function singl market believ citizen busi benefit fulli (1 fois | 1.5%)
#
# Mot : 'TRANSPAR' (Total: 61)
#    Contexte : transpar ...
#       -> consist implement stabil growth pact macroeconom imbal procedur (10 fois | 16.4%)
#       -> consist implement european union fiscal econom govern framework (8 fois | 13.1%)
#       -> robust busi model key strengthen bank resili shock (7 fois | 11.5%)
#       -> consist implement eu fiscal econom govern framework time (4 fois | 6.6%)
#       -> well robust busi model key strengthen bank resili (3 fois | 4.9%)
#       -> robust busi model remain key strengthen bank resili (3 fois | 4.9%)
#       -> without delay help govern bring budget deficit debt (2 fois | 3.3%)
#
# Mot : 'SUCCESS' (Total: 58)
#    Contexte : success ...
#       -> conclus negoti european commiss liaison ecb intern monetari (3 fois | 5.2%)
#       -> conclus doha round world trade negoti also help (2 fois | 3.4%)
#       -> polici mitig advers impact incom employ extent suppli (2 fois | 3.4%)
#       -> launch day onward eurosystem - ecb eleven nation (1 fois | 1.7%)
#       -> settl today decis amount liquid alloc bank system (1 fois | 1.7%)
#       -> also govern council obvious recognis learn process still (1 fois | 1.7%)
#       -> declin level industri product appear stabilis month april (1 fois | 1.7%)
#
# Mot : 'BETTER' (Total: 57)
#    Contexte : better ...
#       -> withstand extern shock would also elimin great deal (2 fois | 3.5%)
#       -> alloc utilis capit human resourc enhanc euro area (2 fois | 3.5%)
#       -> expect look ahead take account number temporari factor (2 fois | 3.5%)
#       -> expect econom fiscal develop make full use room (2 fois | 3.5%)
#       -> prospect global demand bolster sizeabl fiscal stimulu progress (2 fois | 3.5%)
#       -> exploit growth employ potenti decis structur measur field (1 fois | 1.8%)
#       -> accommod challeng ahead among chang find upgrad director (1 fois | 1.8%)
#
# Mot : 'ADEQU' (Total: 57)
#    Contexte : adequ ...
#       -> transmiss monetari polici financ condit euro area countri (18 fois | 31.6%)
#       -> public infrastructur vital increas invest boost job creation (7 fois | 12.3%)
#       -> access financ therebi lay foundat sustain growth financi (6 fois | 10.5%)
#       -> public infrastructur vital increas product invest boost job (4 fois | 7.0%)
#       -> access financ therebi lay foundat sustain growth job (3 fois | 5.3%)
#       -> scope expand provis credit privat sector essenti bank (2 fois | 3.5%)
#       -> order preserv steadi gdp employ growth medium term (1 fois | 1.8%)
#
# Mot : 'DESPIT' (Total: 55)
#    Contexte : despit ...
#       -> improv dynam loan non-financi corpor remain subdu continu (5 fois | 9.1%)
#       -> improv develop loan enterpris continu reflect lag relationship (2 fois | 3.6%)
#       -> introduct euro howev still clear gap servic level (1 fois | 1.8%)
#       -> effect oil price shock posit factor lend support (1 fois | 1.8%)
#       -> acceler growth current monetari develop signal risk price (1 fois | 1.8%)
#       -> continu high unemploy euro area firm continu report (1 fois | 1.8%)
#       -> rather posit outlook assess short-term dynam real activ (1 fois | 1.8%)
#
# Mot : 'STABL' (Total: 54)
#    Contexte : stabl ...
#       -> stand around per cent risk assess risk econom (4 fois | 7.4%)
#       -> money market condit therebi provid support gradual recoveri (3 fois | 5.6%)
#       -> pass-through monetari polici measur put place sinc june (3 fois | 5.6%)
#       -> rate price increas offset develop level servic good (1 fois | 1.9%)
#       -> march line assess made occas previou meet govern (1 fois | 1.9%)
#       -> macroeconom environ continu addit treati provid clear alloc (1 fois | 1.9%)
#       -> sustain public financ therebi contribut significantli confid favour (1 fois | 1.9%)
#
# Mot : 'EXCEPT' (Total: 53)
#    Contexte : except ...
#       -> high govern council continu keep inflat expect firmli (4 fois | 7.5%)
#       -> uncertainti follow data-depend meeting-by-meet approach determin appropri monetari (4 fois | 7.5%)
#       -> low level interest rate across entir matur spectrum (2 fois | 3.8%)
#       -> challeng call upon meet respons accordingli confirm remain (2 fois | 3.8%)
#       -> challeng lie ahead expect bank sector make contribut (2 fois | 3.8%)
#       -> high degre uncertainti overal risk econom growth remain (2 fois | 3.8%)
#       -> high accordingli continu monitor close develop period ahead (2 fois | 3.8%)
#
# Mot : 'DEPEND' (Total: 50)
#    Contexte : depend ...
#       -> futur develop economi financi market excess liquid persist (2 fois | 4.0%)
#       -> crucial durat effect contain measur success polici mitig (2 fois | 4.0%)
#       -> cours pandem progress vaccin current rise inflat expect (2 fois | 4.0%)
#       -> favour financ condit sector economi market interest rate (2 fois | 4.0%)
#       -> policy-mak play part let give floor vice-presid introduc (1 fois | 2.0%)
#       -> behaviour number factor particular wage develop remain line (1 fois | 2.0%)
#       -> much progress made enhanc flexibl labour good market (1 fois | 2.0%)
#
# Mot : 'ENCOURAG' (Total: 49)
#    Contexte : encourag ...
#       -> firm increas invest today bring forward econom recoveri (4 fois | 8.2%)
#       -> push ahead reform relat size structur public expenditur (2 fois | 4.1%)
#       -> household expand consumpt firm increas invest today thu (2 fois | 4.1%)
#       -> hand ongo pandem includ spread viru mutat implic (2 fois | 4.1%)
#       -> less experienc counterparti particip tender govern council take (1 fois | 2.0%)
#       -> higher invest help prevent emerg capac constraint econom (1 fois | 2.0%)
#       -> develop cross-bord payment system enabl public benefit fulli (1 fois | 2.0%)
#
# Mot : 'REBOUND' (Total: 49)
#    Contexte : rebound ...
#       -> third quarter contain measur eas support favour financ (2 fois | 4.1%)
#       -> strongli rose per cent quarter quarter third quarter (2 fois | 4.1%)
#       -> econom activ cours medium term recoveri euro area (2 fois | 4.1%)
#       -> china could give fresh boost commod price foreign (2 fois | 4.1%)
#       -> faster inflat could turn higher wage profit increas (2 fois | 4.1%)
#       -> februari togeth increas capac utilis industri confid april (1 fois | 2.0%)
#       -> oil price increas indirect tax administ price moreov (1 fois | 2.0%)
#
# Mot : 'INNOV' (Total: 44)
#    Contexte : innov ...
#       -> product progress direct enhanc underli growth potenti euro (2 fois | 4.5%)
#       -> urgent need speed restructur invest creat busi opportun (2 fois | 4.5%)
#       -> also urgent need speed restructur invest creat new (2 fois | 4.5%)
#       -> could larg howev progress made field structur reform (1 fois | 2.3%)
#       -> likewis govern pursu determin reform regard size structur (1 fois | 2.3%)
#       -> economi jean-claud trichet presid european central bank luca (1 fois | 2.3%)
#       -> economi jean-claud trichet presid ecb luca papademo vice (1 fois | 2.3%)
#
# Mot : 'ADVANTAG' (Total: 40)
#    Contexte : advantag ...
#       -> govern support measur recapitalis sum current key ecb (10 fois | 25.0%)
#       -> govern support measur recapitalis particular bank current limit (6 fois | 15.0%)
#       -> govern measur support financi sector particularli regard recapitalis (5 fois | 12.5%)
#       -> exercis improv capit solvenc posit therebi contribut overcom (2 fois | 5.0%)
#       -> present stanc monetari polici take inform account govern (1 fois | 2.5%)
#       -> econom recoveri increas overal econom effici enhanc longer-term (1 fois | 2.5%)
#       -> favour econom environ appropri ambiti fiscal target part (1 fois | 2.5%)
#
# Mot : 'INTEGR' (Total: 39)
#    Contexte : integr ...
#       -> financi framework help accomplish object futur singl supervisori (3 fois | 7.7%)
#       -> complet save invest union bank union ambiti timet (2 fois | 5.1%)
#       -> euro area money market initi day money market (1 fois | 2.6%)
#       -> euro money market made possibl consolid treasuri manag (1 fois | 2.6%)
#       -> money capit market import consolid process welcom gener (1 fois | 2.6%)
#       -> greek credit institut eurosystem 's minimum reserv system (1 fois | 2.6%)
#       -> financi servic sector expand econom activ increas employ (1 fois | 2.6%)
#
# Mot : 'BOLSTER' (Total: 33)
#    Contexte : bolster ...
#       -> resili euro area economi improv function econom monetari (12 fois | 36.4%)
#       -> confid therebi underpin econom activ safeguard medium-term price (3 fois | 9.1%)
#       -> consum busi confid shorter horizon jean-claud trichet presid (2 fois | 6.1%)
#       -> resili euro area economi mario draghi presid ecb (2 fois | 6.1%)
#       -> sizeabl fiscal stimulu progress vaccin campaign encourag hand (2 fois | 6.1%)
#       -> confid euro area 's growth potenti particularli mean (1 fois | 3.0%)
#       -> public confid sustain govern financ euro area govern (1 fois | 3.0%)
#
# Mot : 'EXCEL' (Total: 32)
#    Contexte : excel ...
#       -> organis today meet govern council report outcom meet (8 fois | 25.0%)
#       -> organis today meet govern council report outcom today (5 fois | 15.6%)
#       -> organis meet govern council let report outcom meet (3 fois | 9.4%)
#       -> organis meet govern council report outcom today meet (3 fois | 9.4%)
#       -> organis today meet govern council govern council today (3 fois | 9.4%)
#       -> opportun proceed swiftli toward fulfil object stabil growth (1 fois | 3.1%)
#       -> organis meet meet today took place except circumst (1 fois | 3.1%)
#
# Mot : 'ATTRACT' (Total: 31)
#    Contexte : attract ...
#       -> monetari asset compar highli remuner longer-term instrument outsid (5 fois | 16.1%)
#       -> sourc fund bank support bank lend firm household (3 fois | 9.7%)
#       -> short-term instrument includ continu declin compar highli remuner (2 fois | 6.5%)
#       -> domest investor also contribut increas attract investor locat (1 fois | 3.2%)
#       -> investor locat abroad overal consist act line respons (1 fois | 3.2%)
#       -> also reflect fact consum need higher level transact (1 fois | 3.2%)
#       -> entri willem f duisenberg presid european central bank (1 fois | 3.2%)
#
# Mot : 'CONSTRUCT' (Total: 31)
#    Contexte : construct ...
#       -> temporari natur accordingli govern council continu monitor develop (7 fois | 22.6%)
#       -> temporari natur let explain assess greater detail start (7 fois | 22.6%)
#       -> temporari natur remain firmli commit price stabil medium (3 fois | 9.7%)
#       -> activ howev high growth rate first quarter might (1 fois | 3.2%)
#       -> activ therefor order assess underli momentum euro area (1 fois | 3.2%)
#       -> temporari natur remain firmli commit maintain price stabil (1 fois | 3.2%)
#       -> invest also strengthen addit broad-bas global recoveri support (1 fois | 3.2%)
#
# Mot : 'BEST' (Total: 27)
#    Contexte : best ...
#       -> way adapt liquid provis chang condit initi period (1 fois | 3.7%)
#       -> way allow economi take full advantag present stanc (1 fois | 3.7%)
#       -> way avoid uncertainti regard futur cours monetari polici (1 fois | 3.7%)
#       -> contribut monetari polici make ensur sustain process econom (1 fois | 3.7%)
#       -> contribut sustain growth second euro area countri much (1 fois | 3.7%)
#       -> contribut monetari polici make regard preserv price stabil (1 fois | 3.7%)
#       -> practic success countri eventu provid benchmark countri measur (1 fois | 3.7%)
#
# Mot : 'HIGHEST' (Total: 27)
#    Contexte : highest ...
#       -> prioriti govern council believ current monetari polici stanc (4 fois | 14.8%)
#       -> seen sinc earli thu counterpart consid main driver (2 fois | 7.4%)
#       -> standard includ wide rang sophist secur featur ecb (1 fois | 3.7%)
#       -> level observ sinc late develop exchang rate euro (1 fois | 3.7%)
#       -> observ sinc mid- pictur strong growth domest demand (1 fois | 3.7%)
#       -> prioriti luca papademo vice-presid european central bank frankfurt (1 fois | 3.7%)
#       -> prioriti countri concern re-establish commit consolid order avoid (1 fois | 3.7%)
#
# Mot : 'UPTURN' (Total: 26)
#    Contexte : upturn ...
#       -> loan growth therebi support recoveri real economi sum (2 fois | 7.7%)
#       -> larg due acceler overnight deposit turn may explain (1 fois | 3.8%)
#       -> long-term interest rate euro area sinc end may (1 fois | 3.8%)
#       -> long-term interest rate euro area seen sinc earli (1 fois | 3.8%)
#       -> econom growth cours year downsid risk pertain project (1 fois | 3.8%)
#       -> euro area good chanc continu price stabil howev (1 fois | 3.8%)
#       -> growth cours year fact industri product data period (1 fois | 3.8%)
#
# Mot : 'GREAT' (Total: 26)
#    Contexte : great ...
#       -> attent develop period come allow explain assess greater (3 fois | 11.5%)
#       -> attent develop period come turn fiscal polici govern (2 fois | 7.7%)
#       -> pleasur announc launch ecb 's work paper seri (1 fois | 3.8%)
#       -> pleasur announc import mileston along road introduct euro (1 fois | 3.8%)
#       -> vigil part monetari polici recent increas oil price (1 fois | 3.8%)
#       -> contribut euro area remain attract domest investor also (1 fois | 3.8%)
#       -> opportun make progress bring high level unemploy euro (1 fois | 3.8%)
#
# Mot : 'ADVANC' (Total: 22)
#    Contexte : advanc ...
#       -> consist inflat stabilis two per cent medium term (2 fois | 9.1%)
#       -> bank industri object set eurosystem identifi outstand issu (1 fois | 4.5%)
#       -> made time high real gdp growth although mani (1 fois | 4.5%)
#       -> area environ weaker econom activ need properli address (1 fois | 4.5%)
#       -> copi monthli bulletin section cover project advanc copi (1 fois | 4.5%)
#       -> copi made avail shortli end press confer hard (1 fois | 4.5%)
#       -> result improv profit underpin busi invest moreov recoveri (1 fois | 4.5%)
#
# Mot : 'ATTAIN' (Total: 18)
#    Contexte : attain ...
#       -> budgetari posit close balanc surplu high public debt-to-gdp (2 fois | 11.1%)
#       -> busi confid consider improv euro area past month (1 fois | 5.6%)
#       -> budgetari posit close balanc surplu requir stabil growth (1 fois | 5.6%)
#       -> budgetari posit line stabil growth pact gradual creat (1 fois | 5.6%)
#       -> sound budgetari posit end respect programm horizon despit (1 fois | 5.6%)
#       -> consolid object specifi latest stabil programm strongli urg (1 fois | 5.6%)
#       -> budgetari posit close balanc surplu horizon stabil programm (1 fois | 5.6%)
#
# Mot : 'ABL' (Total: 16)
#    Contexte : abl ...
#       -> identifi banknot genuin respect ecb co-oper european commiss (1 fois | 6.2%)
#       -> transfer money rapidli reliabl cheapli one part european (1 fois | 6.2%)
#       -> weather centuri date chang without encount major problem (1 fois | 6.2%)
#       -> reli mainten price stabil medium term conclus respons (1 fois | 6.2%)
#       -> recognis accept euro banknot organis euro area nation (1 fois | 6.2%)
#       -> maintain price stabil therebi contribut sound econom growth (1 fois | 6.2%)
#       -> maintain price stabil medium term thu decid keep (1 fois | 6.2%)
#
# Mot : 'SMOOTHLI' (Total: 16)
#    Contexte : smoothli ...
#       -> continu favour impact cost avail credit firm household (2 fois | 12.5%)
#       -> januari centuri date chang also review cross-bord retail (1 fois | 6.2%)
#       -> posit outcom reflect care prepar bank financi commun (1 fois | 6.2%)
#       -> increas energi price sever way one way step (1 fois | 6.2%)
#       -> look back first two half year sinc start (1 fois | 6.2%)
#       -> howev well-balanc nation econom polici complement singl monetari (1 fois | 6.2%)
#       -> look forward good start relationship european citizen new (1 fois | 6.2%)
#
# Mot : 'HAPPI' (Total: 13)
#    Contexte : happi ...
#       -> new year would also like take opportun welcom (6 fois | 46.2%)
#       -> new year report outcom today meet govern council (3 fois | 23.1%)
#       -> new year vice-presid pleas welcom press confer report (3 fois | 23.1%)
#       -> posit report overal transit euro within eurosystem bank (1 fois | 7.7%)
#
# Mot : 'ACCOMPLISH' (Total: 13)
#    Contexte : accomplish ...
#       -> object futur singl supervisori mechan ssm one main (3 fois | 23.1%)
#       -> object sum econom analysi indic price develop remain (3 fois | 23.1%)
#       -> object particular govern council emphasis futur singl supervisori (2 fois | 15.4%)
#       -> satisfact regard changeov weekend ecb inform mean first (1 fois | 7.7%)
#       -> necessari adjust jean-claud trichet presid ecb v tor (1 fois | 7.7%)
#       -> object singl supervisori mechan ssm one main build (1 fois | 7.7%)
#       -> object particular light recent experi must emphasis futur (1 fois | 7.7%)
#
# Mot : 'PLEASUR' (Total: 12)
#    Contexte : pleasur ...
#       -> welcom press confer vice presid report outcom today (3 fois | 25.0%)
#       -> chair meet govern council ecb delight proceed well-establish (2 fois | 16.7%)
#       -> announc launch ecb 's work paper seri initi (1 fois | 8.3%)
#       -> announc import mileston along road introduct euro banknot (1 fois | 8.3%)
#       -> welcom press confer helsinki govern council european central (1 fois | 8.3%)
#       -> welcom press confer vice-presid report outcom today meet (1 fois | 8.3%)
#       -> see germani mani time futur mr presid floor (1 fois | 8.3%)
#
# Mot : 'BENEFICI' (Total: 12)
#    Contexte : benefici ...
#       -> employ growth euro area improv resili euro area (2 fois | 16.7%)
#       -> effect reform therebi make euro area resili global (2 fois | 16.7%)
#       -> would warn chang text treati regul form basi (1 fois | 8.3%)
#       -> regard european commiss propos improv implement prevent arm (1 fois | 8.3%)
#       -> turn consum price annual hicp inflat novemb accord (1 fois | 8.3%)
#       -> promot growth employ essenti turn agre reform plan (1 fois | 8.3%)
#       -> promot growth employ enhanc resili euro area economi (1 fois | 8.3%)
#
# Mot : 'INSIGHT' (Total: 12)
#    Contexte : insight ...
#       -> outlook price develop medium longer-term horizon provid monetari (3 fois | 25.0%)
#       -> financi institut household firm respond financi market volatil (2 fois | 16.7%)
#       -> financi institut household firm respond financi market turmoil (2 fois | 16.7%)
#       -> outlook price develop medium longer-term horizon latest monetari (1 fois | 8.3%)
#       -> risk price stabil medium longer term past month (1 fois | 8.3%)
#       -> inflat prospect medium longer horizon money credit continu (1 fois | 8.3%)
#       -> bank behaviour financ condit particular strength matur sector (1 fois | 8.3%)
#
# Mot : 'ENABL' (Total: 11)
#    Contexte : enabl ...
#       -> print plate made product pilot seri start septemb (1 fois | 9.1%)
#       -> public benefit fulli singl currenc eurosystem drawn set (1 fois | 9.1%)
#       -> sever govern council member attend first gather new (1 fois | 9.1%)
#       -> involv becom familiar basic rule follow prepar introduct (1 fois | 9.1%)
#       -> euro area economi respond flexibl futur therebi underpin (1 fois | 9.1%)
#       -> euro area member achiev medium-term object aim latest (1 fois | 9.1%)
#       -> euro area countri achiev medium-term object aim latest (1 fois | 9.1%)
#
# Mot : 'CONDUC' (Total: 11)
#    Contexte : conduc ...
#       -> maintain price stabil medium term contain inflationari expect (1 fois | 9.1%)
#       -> maintain price stabil domest level ensur robust growth (1 fois | 9.1%)
#       -> stronger growth potenti euro area also like reiter (1 fois | 9.1%)
#       -> econom growth employ creation factor facilit mainten price (1 fois | 9.1%)
#       -> restor higher econom growth euro area interest rate (1 fois | 9.1%)
#       -> econom growth end militari action iraq import downsid (1 fois | 9.1%)
#       -> foster employ growth final measur long-term inflat expect (1 fois | 9.1%)
#
# Mot : 'REGAIN' (Total: 9)
#    Contexte : regain ...
#       -> momentum number reason weaker real gdp growth second (1 fois | 11.1%)
#       -> momentum becom broadli base sustain first half look (1 fois | 11.1%)
#       -> suffici room budgetari manoeuvr regard recent ecofin council (1 fois | 11.1%)
#       -> suffici room budgetari manoeuvr regard current govern commit (1 fois | 11.1%)
#       -> sustain public financ reduc risk premia interest rate (1 fois | 11.1%)
#       -> competit pre-condit stabl econom growth natur complement implement (1 fois | 11.1%)
#       -> competit set foundat sustain growth support return macroeconom (1 fois | 11.1%)
#
# Mot : 'EASIER' (Total: 9)
#    Contexte : easier ...
#       -> financ condit fall inflat allow domest consumpt invest (3 fois | 33.3%)
#       -> busi boost employ thu enhanc euro area growth (1 fois | 11.1%)
#       -> borrow condit firm household underpin consum spend busi (1 fois | 11.1%)
#       -> borrow condit firm household support consum spend busi (1 fois | 11.1%)
#       -> financ condit declin inflat lead faster rebound consumpt (1 fois | 11.1%)
#       -> financ condit part past interest rate cut help (1 fois | 11.1%)
#       -> financ condit underpin domest demand includ hous market (1 fois | 11.1%)
#
# Mot : 'OPTIMIST' (Total: 8)
#    Contexte : optimist ...
#       -> outlook retail sale recent pattern employ unemploy suggest (1 fois | 12.5%)
#       -> prospect econom activ euro area time expect inflat (1 fois | 12.5%)
#       -> outlook euro area economi today 's meet govern (1 fois | 12.5%)
#       -> regard econom outlook euro area posit outlook need (1 fois | 12.5%)
#       -> assess market particip econom growth prospect euro area (1 fois | 12.5%)
#       -> assess econom outlook insid outsid euro area whole (1 fois | 12.5%)
#       -> assumpt econom develop addit countri implement fewer consolid (1 fois | 12.5%)
#
# Mot : 'GREATLI' (Total: 8)
#    Contexte : greatli ...
#       -> facilit monetari polici task maintain price stabil environ (1 fois | 12.5%)
#       -> facilit individu member countri make convinc progress structur (1 fois | 12.5%)
#       -> facilit spend invest decis euro area willem f (1 fois | 12.5%)
#       -> enhanc social partner fulli commit object make euro (1 fois | 12.5%)
#       -> depend extent pace futur revers past portfolio shift (1 fois | 12.5%)
#       -> depend futur develop economi financi market excess liquid (1 fois | 12.5%)
#       -> benefit flexibl labour product market speed necessari changeov (1 fois | 12.5%)
#
# Mot : 'SATISFACTORI' (Total: 8)
#    Contexte : satisfactori ...
#       -> look forward ongo concern emerg second-round effect wage (1 fois | 12.5%)
#       -> look futur ongo concern confirm overal econom growth (1 fois | 12.5%)
#       -> path uncertainti current overshadow world economi diminish major (1 fois | 12.5%)
#       -> expect month ago least result higher oil price (1 fois | 12.5%)
#       -> expect month ago howev econom outlook still subject (1 fois | 12.5%)
#       -> expect month ago recent week exchang rate euro (1 fois | 12.5%)
#       -> pictur short term due partli sequenc advers rather (1 fois | 12.5%)
#
# Mot : 'RESOLV' (Total: 8)
#    Contexte : resolv ...
#       -> determin ensur singl currenc would becom realiti today (1 fois | 12.5%)
#       -> uncertainti therebi mitig associ risk euro area economi (1 fois | 12.5%)
#       -> risk outlook growth inflat compar expect decemb risk (1 fois | 12.5%)
#       -> benign outcom growth lesser extent inflat would higher (1 fois | 12.5%)
#       -> swiftli could lift sentiment spur activ increas defenc (1 fois | 12.5%)
#       -> swiftli could lift sentiment spur activ higher defenc (1 fois | 12.5%)
#       -> faster expect outlook inflat remain uncertain usual result (1 fois | 12.5%)
#
# Mot : 'ASSUR' (Total: 7)
#    Contexte : assur ...
#       -> wage negoti prospect price stabil remain favour fact (1 fois | 14.3%)
#       -> govern council maintain price stabil medium term introductori (1 fois | 14.3%)
#       -> must given challeng inde tackl decis manner clear (1 fois | 14.3%)
#       -> determin preserv purchas power money year come thu (1 fois | 14.3%)
#       -> govern council total solidar spanish peopl banco de (1 fois | 14.3%)
#       -> offici measur accur continu maintain price stabil futur (1 fois | 14.3%)
#       -> let explain assess greater detail start econom analysi (1 fois | 14.3%)
#
# Mot : 'STRONGEST' (Total: 6)
#    Contexte : strongest ...
#       -> level perform current record emerg market economi south-east (1 fois | 16.7%)
#       -> perform mani year may therefor moder still remain (1 fois | 16.7%)
#       -> euro area time latest indic output demand remain (1 fois | 16.7%)
#       -> dynam mani year nevertheless euro area export continu (1 fois | 16.7%)
#       -> aggreg growth euro area group countri sinc signific (1 fois | 16.7%)
#       -> contract sinc start euro amid weak lend reduct (1 fois | 16.7%)
#
# Mot : 'PROSPER' (Total: 6)
#    Contexte : prosper ...
#       -> european citizen longer term jean-claud trichet presid ecb (1 fois | 16.7%)
#       -> past decad ongo transform world economi reflect technolog (1 fois | 16.7%)
#       -> citizen europ member state fulfil converg criteria laid (1 fois | 16.7%)
#       -> recoveri readi take christin lagard presid ecb lui (1 fois | 16.7%)
#       -> recoveri import european leader quickli agre ambiti packag (1 fois | 16.7%)
#       -> recoveri order fulli reach potenti packag need firmli (1 fois | 16.7%)
#
# Mot : 'ENJOY' (Total: 5)
#    Contexte : enjoy ...
#       -> better expect econom fiscal develop make full use (2 fois | 40.0%)
#       -> robust growth activ also acceler industrialis countri recoveri (1 fois | 20.0%)
#       -> low long-term interest rate conduc econom growth employ (1 fois | 20.0%)
#       -> higher incom spend global recoveri ongo fiscal monetari (1 fois | 20.0%)
#
# Mot : 'EXCLUS' (Total: 4)
#    Contexte : exclus ...
#       -> right approv volum coin issu euro area member (2 fois | 50.0%)
#       -> euro area-wid perspect underpin two-pillar analysi govern council (1 fois | 25.0%)
#       -> russian bank swift far caus sever strain money (1 fois | 25.0%)
#
# Mot : 'DELIGHT' (Total: 4)
#    Contexte : delight ...
#       -> proceed well-establish practic real-tim commun report outcom meet (2 fois | 50.0%)
#       -> posit respons partnership programm receiv import commun channel (1 fois | 25.0%)
#       -> proceed report outcom meet togeth vice-presid govern council (1 fois | 25.0%)
#
# Mot : 'DISTINCT' (Total: 4)
#    Contexte : distinct ...
#       -> temporari short-term factor one hand last natur detail (1 fois | 25.0%)
#       -> temporari short-term factor one hand last natur develop (1 fois | 25.0%)
#       -> temporari short-term factor one hand factor last natur (1 fois | 25.0%)
#       -> mind govern council view uncertainti surround outlook econom (1 fois | 25.0%)
#
# Mot : 'EMPOW' (Total: 4)
#    Contexte : empow ...
#       -> singl market stress urgent need reform provid concret (1 fois | 25.0%)
#       -> singl market implement eu revis econom govern framework (1 fois | 25.0%)
#       -> singl market welcom european commiss assess govern medium-term (1 fois | 25.0%)
#       -> singl market govern implement commit eu econom govern (1 fois | 25.0%)
#
# Mot : 'SUCCEED' (Total: 3)
#    Contexte : succeed ...
#       -> maintain sound budgetari posit sever countri essenti fiscal (1 fois | 33.3%)
#       -> embed comprehens reform programm adequ prepar long-term fiscal (1 fois | 33.3%)
#       -> preserv favour financ condit necessari secur sustain converg (1 fois | 33.3%)
#
# Mot : 'DESIR' (Total: 3)
#    Contexte : desir ...
#       -> wage settlement move away automat backward-look index mechan (1 fois | 33.3%)
#       -> govern council strongli welcom european commiss alert mechan (1 fois | 33.3%)
#       -> chang regulatori environ work relev institut effect fourth (1 fois | 33.3%)
#
# Mot : 'OUTPERFORM' (Total: 3)
#    Contexte : outperform ...
#       -> expect consum becom confid save less current expect (2 fois | 66.7%)
#       -> expect consum spend current expect draw rapidli save (1 fois | 33.3%)
#
# Mot : 'SATISFACT' (Total: 2)
#    Contexte : satisfact ...
#       -> changeov one integr euro area money market initi (1 fois | 50.0%)
#       -> regard changeov weekend ecb inform mean first press (1 fois | 50.0%)
#
# Mot : 'ABUND' (Total: 2)
#    Contexte : abund ...
#       -> liquid therefor eurosystem morn conduct liquidity-absorb oper amount (1 fois | 50.0%)
#       -> time cost firm issu equiti still high mani (1 fois | 50.0%)
#
# Mot : 'EASILI' (Total: 2)
#    Contexte : easili ...
#       -> absorb past willem f duisenberg presid european central (1 fois | 50.0%)
#       -> succeed embed comprehens reform programm adequ prepar long-term (1 fois | 50.0%)
#
# Mot : 'PERFECT' (Total: 2)
#    Contexte : perfect ...
#       -> organis today meet let report outcom today meet (1 fois | 50.0%)
#       -> organis let report outcom today meet also attend (1 fois | 50.0%)
#
# Mot : 'ALLIANC' (Total: 1)
#    Contexte : allianc ...
#       -> increas role euro factor encourag process consolid via (1 fois | 100.0%)
#
# Mot : 'IMPRESS' (Total: 1)
#    Contexte : impress ...
#       -> cost stem increas oil price could avoid relax (1 fois | 100.0%)
#
# Mot : 'CREATIV' (Total: 1)
#    Contexte : creativ ...
#       -> concept mass media campaign start septemb websit dedic (1 fois | 100.0%)
#
# Mot : 'WINNER' (Total: 1)
#    Contexte : winner ...
#       -> euro superstar competit competit organis ecb nation central (1 fois | 100.0%)
#
# Mot : 'DILIG' (Total: 1)
#    Contexte : dilig ...
#       -> implement appropri procedur respons procedur lie european commiss (1 fois | 100.0%)
#
# Mot : 'IDEAL' (Total: 1)
#    Contexte : ideal ...
#       -> opportun strengthen effort toward implement comprehens structur reform (1 fois | 100.0%)
#
# Mot : 'REWARD' (Total: 1)
#    Contexte : reward ...
#       -> form higher growth sustain public financ consolid reform (1 fois | 100.0%)
#
# Mot : 'PERFECTLI' (Total: 1)
#    Contexte : perfectli ...
#       -> organis meet deepli regret mr matti vanhala resign (1 fois | 100.0%)
#
# Mot : 'VALUABL' (Total: 1)
#    Contexte : valuabl ...
#       -> support current econom upsw jean-claud trichet presid ecb (1 fois | 100.0%)
#
# Mot : 'LEADERSHIP' (Total: 1)
#    Contexte : leadership ...
#       -> ecb eurosystem success pass stage establish initi challeng (1 fois | 100.0%)
#
# Mot : 'SATISFI' (Total: 1)
#    Contexte : satisfi ...
#       -> specif elig criteria respons entail accept credit claim (1 fois | 100.0%)
#
# Mot : 'FAVOR' (Total: 1)
#    Contexte : favor ...
#       -> bank lend condit loan enterpris loan hous purchas (1 fois | 100.0%)

# %%
# Mots à retirer ABSOLUMENT des dictionnaires LM (Loughran-McDonald)

# 1. NETTOYAGE DES NÉGATIFS (Faux alarmes)
kill_list_neg = [
    # Structurel / Politesse
    'question', 'questions', 'vice', 'general', 'press', 'lie',

    # Termes Techniques / Neutres (BCE Speak)
    'risk', 'risks',                 # "Balance of risks"
    'deficit', 'deficits',           # "Budget deficit" (Data)
    'liquid', 'liquidity',           # "Liquidity management"
    'object', 'objective',           # "Primary objective"
    'dispos', 'disposable',          # "Disposable income"
    'lag', 'lagged',                 # "Time lags"
    'eas', 'easing',                 # "Quantitative easing"
    'implic', 'implication',         # "Implications for policy"
    'restructur', 'restructuring',   # Souvent positif (réformes)
    'prevent',                       # Action proactive

    # Ambigu (Souvent utilisé pour décrire une baisse de l'inflation = Bien)
    'decline', 'declined', 'declining',
    'dampen', 'dampened',
    'limit', 'limited',              # "Risks are limited"

    # Intensifieurs neutres
    'crucial', 'persistent', 'challenges', 'urgent'
]

# 2. NETTOYAGE DES POSITIFS (Bruit & Politesse)
kill_list_pos = [
    # Politesse
    'pleas', 'pleased', 'pleasure', 'happy', 'kind', 'welcome', 'good', # "Good afternoon"

    # Termes Techniques / Neutres
    'inform', 'information',         # "Incoming information" (Data)
    'opportun', 'opportunity',       # "Opportunity cost"
    'conclus', 'conclusion',         # "In conclusion"
    'share',                         # "Share of GDP"
    'lead', 'leading'                # "Leading to inflation" (Souvent négatif en fait)
]
# Application du filtre
final_neg_list = set([w for w in neg_words_stemmed if w not in kill_list_neg])
final_pos_list = set([w for w in pos_words_stemmed if w not in kill_list_pos])

print(f"Négatifs restants : {len(final_neg_list)} (Nettoyés : {len(neg_words_stemmed) - len(final_neg_list)})")
print(f"Positifs restants : {len(final_pos_list)} (Nettoyés : {len(pos_words_stemmed) - len(final_pos_list)})")
# Out:
# Négatifs restants : 895 (Nettoyés : 16)
# Positifs restants : 143 (Nettoyés : 6)

# %%
import pandas as pd

# Application du nettoyage
for w in kill_list_neg:
    if w in neg_words_stemmed:
        neg_words_stemmed.remove(w)

# 4. SUPPRESSION DES FAUX POSITIFS (Politesse)
for w in kill_list_pos:
    if w in pos_words_stemmed:
        pos_words_stemmed.remove(w)

# 5. CALCUL FINAL DU SCORE
def compute_pessimism_final(text):
    if not isinstance(text, str):
        return 0

    # Tokenisation simple (le texte est déjà cleané/minuscule)
    tokens = text.split()
    total = len(tokens)

    if total == 0: return 0

    n_pos = sum(1 for t in tokens if t in pos_words_stemmed)
    n_neg = sum(1 for t in tokens if t in neg_words_stemmed)

    # Formule : (Neg - Pos) / Total * 100
    # Rappel : Un score négatif signifie Optimiste (car Pos > Neg)
    return ((n_neg - n_pos) / total) * 100

# Appliquer sur la colonne nettoyée (sans Q&A)
df['pessimism_final'] = df['clean_text'].apply(compute_pessimism_final)

# Calcul des statistiques pour PESSIMISM
pessism_stats = {
    'Moyenne': df['pessimism_final'].mean(),
    'Écart-type': df['pessimism_final'].std(),
    'Minimum': df['pessimism_final'].min(),
    '1er Quartile': df['pessimism_final'].quantile(0.25),
    'Médiane': df['pessimism_final'].median(),
    '3ème Quartile': df['pessimism_final'].quantile(0.75),
    'Maximum': df['pessimism_final'].max()
}
# Affichage des résultats
print("\n=== STATISTIQUES PESSIMISM ===")
for stat, value in pessism_stats.items():
    print(f"{stat + ':':<15} {value:>10.4f}")
# Out:
# === STATISTIQUES PESSIMISM ===
# Moyenne:           -0.1066
# Écart-type:         1.5453
# Minimum:           -4.3321
# 1er Quartile:      -1.0719
# Médiane:           -0.1229
# 3ème Quartile:      0.9030
# Maximum:            3.8919

# %%
import yfinance as yf

stoxx = yf.download("^STOXX50E", start="1999-01-01", end="2025-12-31")

# Calcul des rendements Logarithmiques (Standard académique)
# Formule : ln(Prix_t / Prix_t-1)
# On utilise 'Close' (ou 'Adj Close' si disponible, souvent identique pour les indices)
price_col = 'Adj Close' if 'Adj Close' in stoxx.columns else 'Close'
stoxx['Log_Return'] = np.log(stoxx[price_col] / stoxx[price_col].shift(1))

# S'assurer que l'index est bien au format Datetime
stoxx.index = pd.to_datetime(stoxx.index)
# Out:
# C:\Users\loren\AppData\Local\Temp\ipykernel_38132\323206678.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stoxx = yf.download("^STOXX50E", start="1999-01-01", end="2025-12-31")
# [*********************100%***********************]  1 of 1 completed

# %%
def calculate_abs_car(date_event):

    date_event = pd.to_datetime(date_event)

    # Trouver l'index (position) du jour de l'annonce dans les données boursières
    # method='nearest' gère les cas où l'annonce tombe un weekend ou jour férié
    if date_event not in stoxx.index:
        # On cherche l'index le plus proche
        idx_loc = stoxx.index.get_indexer([date_event], method='nearest')[0]
    else:
        idx_loc = stoxx.index.get_loc(date_event)

    # --- DÉFINITION DES FENÊTRES (en jours de bourse) ---

    # 1. Fenêtre d'Estimation (Pour calibrer le rendement "normal")
    # On recule de 250 jours et on s'arrête 50 jours avant l'événement
    est_start = idx_loc - 250
    est_end = idx_loc - 50

    # 2. Fenêtre d'Événement (Pour mesurer le choc)
    # 5 jours avant à 5 jours après (Total 11 jours)
    evt_start = idx_loc - 5
    evt_end = idx_loc + 5

    # Sécurité : Vérifier qu'on ne sort pas des limites du tableau
    if est_start < 0 or evt_end >= len(stoxx):
        return np.nan

    # --- CALCULS ---

    # A. Calcul du rendement attendu (Moyenne historique locale)
    # On prend les rendements sur la fenêtre d'estimation
    estimation_returns = stoxx['Log_Return'].iloc[est_start:est_end]
    expected_return = estimation_returns.mean()

    # B. Calcul des rendements anormaux (AR) sur la fenêtre d'événement
    event_returns = stoxx['Log_Return'].iloc[evt_start : evt_end + 1]

    # AR = Rendement Réel - Rendement Attendu
    abnormal_returns = event_returns - expected_return

    # C. CAR = Somme des AR
    car = abnormal_returns.sum()

    # On retourne la VALEUR ABSOLUE en POURCENTAGE
    return car

# %%
print("Calcul des métriques CAR...")
print("-" * 60)

# Conversion de la date
df['date'] = pd.to_datetime(df['date'])

# Calcul des CAR
df['CAR'] = df['date'].apply(calculate_abs_car)
df['ABS_CAR'] = abs(df['CAR']) * 100

# Calcul des statistiques pour CAR
car_stats = {
    'Moyenne': df['CAR'].mean(),
    'Écart-type': df['CAR'].std(),
    'Minimum': df['CAR'].min(),
    '1er Quartile': df['CAR'].quantile(0.25),
    'Médiane': df['CAR'].median(),
    '3ème Quartile': df['CAR'].quantile(0.75),
    'Maximum': df['CAR'].max()
}

# Calcul des statistiques pour ABS_CAR
abs_car_stats = {
    'Moyenne': df['ABS_CAR'].mean(),
    'Écart-type': df['ABS_CAR'].std(),
    'Minimum': df['ABS_CAR'].min(),
    '1er Quartile': df['ABS_CAR'].quantile(0.25),
    'Médiane': df['ABS_CAR'].median(),
    '3ème Quartile': df['ABS_CAR'].quantile(0.75),
    'Maximum': df['ABS_CAR'].max()
}

# Affichage des résultats
print("\n=== STATISTIQUES CAR ===")
for stat, value in car_stats.items():
    print(f"{stat + ':':<15} {value:>10.4f}")

print("\n=== STATISTIQUES |CAR| (en %) ===")
for stat, value in abs_car_stats.items():
    print(f"{stat + ':':<15} {value:>10.4f}%")

print("-" * 60)
# Out:
# Calcul des métriques CAR...
# ------------------------------------------------------------
#
# === STATISTIQUES CAR ===
# Moyenne:           -0.0003
# Écart-type:         0.0511
# Minimum:           -0.3395
# 1er Quartile:      -0.0204
# Médiane:            0.0034
# 3ème Quartile:      0.0275
# Maximum:            0.1328
#
# === STATISTIQUES |CAR| (en %) ===
# Moyenne:            3.3855%
# Écart-type:         3.8128%
# Minimum:            0.0066%
# 1er Quartile:       1.3058%
# Médiane:            2.4620%
# 3ème Quartile:      4.1915%
# Maximum:           33.9480%
# ------------------------------------------------------------

# %%
import pandas_datareader.data as web
import pandas as pd
import numpy as np
import statsmodels.api as sm

# 1. CONFIGURATION DES DATES
start_date = "1999-01-01"
end_date = "2025-12-31"

# ==============================================================================
# A. DELTA MRO (Taux de Refinancement Principal)
# ==============================================================================
# Code FRED pour le taux directeur BCE : "ECBMRRFR" (Main Refinancing Operations)
mro = web.DataReader("ECBMRRFR", "fred", start_date, end_date)

# On veut la variation (Delta) : Taux aujourd'hui - Taux de la veille
# Note : Pour une réunion mensuelle, on regarde le changement par rapport à la dernière réunion.
# Ici, on calcule le changement quotidien, on fera le lien avec la date de réunion plus tard.
mro['DELTA_MRO'] = mro['ECBMRRFR'].diff()

# ==============================================================================
# B. INFLATION (HICP - Euro Area)
# ==============================================================================
# Code FRED : "CP0000EZ19M086NEST" (Harmonized Index of Consumer Prices: All Items for Euro Area)
# C'est un indice mensuel.
hicp = web.DataReader("CP0000EZ19M086NEST", "fred", start_date, end_date)

# L'inflation est le changement en % sur un an (Year-over-Year)
# Formule : (Indice_t / Indice_t-12) - 1
hicp['INFLATION'] = hicp['CP0000EZ19M086NEST'].pct_change(periods=12) * 100

# ==============================================================================
# C. OUTPUT GAP (Écart de Production)
# ==============================================================================
# L'Output Gap n'existe pas "brut". On le calcule à partir du PIB Réel.
# Code FRED : "CLVMNACSCAB1GQEA19" (Real GDP for Euro Area, Trimestriel)
gdp = web.DataReader("CLVMNACSCAB1GQEA19", "fred", start_date, end_date)

# 1. On passe en Logarithme (Standard économétrique)
gdp['log_gdp'] = np.log(gdp['CLVMNACSCAB1GQEA19'])

# 2. Filtre Hodrick-Prescott (HP Filter) pour séparer la Tendance du Cycle
# Le Cycle = L'Output Gap
# Lambda = 1600 pour des données trimestrielles (Règle de Ravn-Uhlig)
cycle, trend = sm.tsa.filters.hpfilter(gdp['log_gdp'].dropna(), lamb=1600)
gdp['OUTPUT_GAP'] = cycle * 100

# 3. Problème : Le PIB est Trimestriel (Q1, Q2...), vos réunions sont Mensuelles.
# Solution : On ré-échantillonne en mensuel avec interpolation linéaire.
output_gap_monthly = gdp['OUTPUT_GAP'].resample('MS').first() # MS = Month Start
output_gap_monthly = output_gap_monthly.interpolate(method='linear')

# ==============================================================================
# 4. FUSION FINALE DANS UN SEUL DATAFRAME MACRO
# ==============================================================================
df_macro = pd.DataFrame()

# On aligne tout sur des fréquences mensuelles ou journalières
# Pour simplifier la fusion avec votre df principal :

# Inflation (Mensuelle)
df_macro['INFLATION'] = hicp['INFLATION']

# Output Gap (Mensuel interpolé)
df_macro['OUTPUT_GAP'] = output_gap_monthly

# On propage les valeurs mensuelles vers l'avant pour remplir les trous
df_macro = df_macro.resample('D').ffill()

# On ajoute le MRO (qui est journalier/fixe par périodes)
# On fusionne sur l'index (les dates)
df_macro = df_macro.join(mro[['ECBMRRFR', 'DELTA_MRO']], how='outer')

# Nettoyage : On remplit les trous du MRO (le taux ne change pas le weekend)
df_macro['ECBMRRFR'] = df_macro['ECBMRRFR'].ffill()
df_macro['DELTA_MRO'] = df_macro['DELTA_MRO'].fillna(0) # Pas de changement les jours sans réunion

# Calcul des statistiques pour OUTPUTGAP
Outputgap_stats = {
    'Moyenne': df_macro['OUTPUT_GAP'].mean(),
    'Écart-type': df_macro['OUTPUT_GAP'].std(),
    'Minimum': df_macro['OUTPUT_GAP'].min(),
    '1er Quartile': df_macro['OUTPUT_GAP'].quantile(0.25),
    'Médiane': df_macro['OUTPUT_GAP'].median(),
    '3ème Quartile': df_macro['OUTPUT_GAP'].quantile(0.75),
    'Maximum': df_macro['OUTPUT_GAP'].max()
}
# Affichage des résultats
print("\n=== STATISTIQUES OUTPUTGAP ===")
for stat, value in Outputgap_stats.items():
    print(f"{stat + ':':<15} {value:>10.4f}")

# Calcul des statistiques pour INFLATION
Inflation_stats = {
    'Moyenne': df_macro['INFLATION'].mean(),
    'Écart-type': df_macro['INFLATION'].std(),
    'Minimum': df_macro['INFLATION'].min(),
    '1er Quartile': df_macro['INFLATION'].quantile(0.25),
    'Médiane': df_macro['INFLATION'].median(),
    '3ème Quartile': df_macro['INFLATION'].quantile(0.75),
    'Maximum': df_macro['INFLATION'].max()
}
# Affichage des résultats
print("\n=== STATISTIQUES INFLATION ===")
for stat, value in Inflation_stats.items():
    print(f"{stat + ':':<15} {value:>10.4f}")

# Calcul des statistiques pour DELTA_MRO
DELTA_MRO_stats = {
    'Moyenne': df_macro['DELTA_MRO'].mean(),
    'Écart-type': df_macro['DELTA_MRO'].std(),
    'Minimum': df_macro['DELTA_MRO'].min(),
    '1er Quartile': df_macro['DELTA_MRO'].quantile(0.25),
    'Médiane': df_macro['DELTA_MRO'].median(),
    '3ème Quartile': df_macro['DELTA_MRO'].quantile(0.75),
    'Maximum': df_macro['DELTA_MRO'].max()
}
# Affichage des résultats
print("\n=== STATISTIQUES CAR ===")
for stat, value in DELTA_MRO_stats.items():
    print(f"{stat + ':':<15} {value:>10.4f}")
# Out:
# === STATISTIQUES OUTPUTGAP ===
# Moyenne:            0.0064
# Écart-type:         1.7757
# Minimum:          -13.5718
# 1er Quartile:      -0.8445
# Médiane:           -0.0327
# 3ème Quartile:      1.0208
# Maximum:            3.3536
#
# === STATISTIQUES INFLATION ===
# Moyenne:            2.1571
# Écart-type:         1.7915
# Minimum:           -0.6199
# 1er Quartile:       1.2966
# Médiane:            2.0289
# 3ème Quartile:      2.4687
# Maximum:           10.6206
#
# === STATISTIQUES CAR ===
# Moyenne:           -0.0000
# Écart-type:         0.0247
# Minimum:           -0.7500
# 1er Quartile:       0.0000
# Médiane:            0.0000
# 3ème Quartile:      0.0000
# Maximum:            0.7500
# C:\Users\loren\miniconda3\Lib\site-packages\statsmodels\tsa\filters\hp_filter.py:100: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   trend = spsolve(I+lamb*K.T.dot(K), x, use_umfpack=use_umfpack)

# %%
# ==============================================================================
# 5. FUSION : ON INJECTE LA MACRO DANS LE TABLEAU DES CONFÉRENCES (df)
# ==============================================================================

# 1. On s'assure que les dates sont bien au format datetime partout
df['date'] = pd.to_datetime(df['date'])
df_macro.index = pd.to_datetime(df_macro.index)

# 2. On trie par date (obligatoire pour merge_asof)
df = df.sort_values('date')
df_macro = df_macro.sort_index()

# 3. La Fusion "Intelligente" (merge_asof)
# Pour chaque conférence dans 'df', on va chercher les données macro du jour même (ou du dernier jour dispo)
df = pd.merge_asof(
    df,
    df_macro[['DELTA_MRO', 'INFLATION', 'OUTPUT_GAP']],
    left_on='date',
    right_index=True,
    direction='backward'
)

# Vérification
print("Fusion terminée ! Aperçu des nouvelles colonnes :")
print(df[['date', 'similarity_sklearn', 'pessimism_final', 'DELTA_MRO', 'INFLATION', 'OUTPUT_GAP']].head())
# Out:
# Fusion terminée ! Aperçu des nouvelles colonnes :
#            date  similarity_sklearn  pessimism_final  DELTA_MRO  INFLATION  \
# 525  1999-01-07            0.000000        -0.208768        0.0        NaN
# 3055 1999-02-04            0.124528         2.536716        0.0        NaN
# 154  1999-03-04            0.154418         1.551313        0.0        NaN
# 2653 1999-04-08            0.094388         0.487013        0.0        NaN
# 2090 1999-05-06            0.098205         0.369004        0.0        NaN
#
#       OUTPUT_GAP
# 525    -1.414378
# 3055   -1.440209
# 154    -1.466040
# 2653   -1.491871
# 2090   -1.238495

# %%
import numpy as np
import statsmodels.api as sm
import pandas as pd

# ------------------------------------------------------------------------------
# 1. PRÉPARATION DES DONNÉES
# ------------------------------------------------------------------------------

# A. Calcul du Log de la Similarité (pour linéariser la tendance, comme dans le papier)
df['log_similarity'] = np.log(df['similarity_sklearn'])

# B. Création de la variable d'INTERACTION (C'est la partie cruciale de l'Eq 9)
# On multiplie le Pessimisme par le Log de la Similarité
df['Interaction_Pess_Sim'] = df['pessimism_final'] * df['log_similarity']

# C. Définition des variables X
# Selon l'image et le tableau 4 (colonnes 3, 4, 5), on ne met QUE l'interaction et les contrôles
variables_explicatives = [
    'Interaction_Pess_Sim', # Le terme clé : logSimilarity * Pessimism
    'DELTA_MRO',            # Contrôle
    'INFLATION',            # Contrôle
    'OUTPUT_GAP'            # Contrôle
]

# Variable cible (Y) : Valeur absolue des rendements anormaux cumulés
variable_cible = 'ABS_CAR'

# Création d'un sous-dataframe propre (sans NaN)
df_reg = df[[variable_cible] + variables_explicatives].dropna()

print(f"Nombre d'observations incluses : {len(df_reg)}")
print("-" * 30)
# Out:
# Nombre d'observations incluses : 166
# ------------------------------
# C:\Users\loren\miniconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# ------------------------------------------------------------------------------
# 2. ESTIMATION DU MODÈLE (OLS)
# ------------------------------------------------------------------------------

Y = df_reg[variable_cible]
X = df_reg[variables_explicatives]

# Ajout de la constante (gamma_0 dans l'équation)
X = sm.add_constant(X)

# Lancement de la régression
model = sm.OLS(Y, X)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                ABS_CAR   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     6.257
# Date:                Sat, 27 Dec 2025   Prob (F-statistic):           0.000480
# Time:                        20:08:39   Log-Likelihood:                -448.84
# No. Observations:                 166   AIC:                             905.7
# Df Residuals:                     162   BIC:                             918.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    2.9044      0.440      6.597      0.000       2.035       3.774
# Interaction_Pess_Sim    -0.1545      0.185     -0.834      0.406      -0.520       0.211
# DELTA_MRO             -2.52e-16    6.2e-17     -4.065      0.000   -3.74e-16    -1.3e-16
# INFLATION                0.1369      0.180      0.759      0.449      -0.219       0.493
# OUTPUT_GAP              -0.6137      0.187     -3.286      0.001      -0.982      -0.245
# ==============================================================================
# Omnibus:                      139.837   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1949.276
# Skew:                           3.032   Prob(JB):                         0.00
# Kurtosis:                      18.654   Cond. No.                     2.19e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.53e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# On s'assure que les dates sont bien au format datetime
df['date'] = pd.to_datetime(df['date'])

# Date de coupure
cutoff_date = '2014-01-01'

# On sépare les données en deux
df_before = df[df['date'] <= cutoff_date]
df_after = df[df['date'] > cutoff_date]

# Création du graphique
plt.figure(figsize=(14, 6))

# 1. La partie "Avant" (Bleu)
sns.lineplot(x='date', y='similarity_sklearn', data=df_before,
             label='1999-2013 (Papier Original)', color='navy')

# 2. La partie "Après" (Rouge)
sns.lineplot(x='date', y='similarity_sklearn', data=df_after,
             label='2014-2025 (Votre Extension)', color='red')

# Titres
plt.title('Évolution de la Similarité : Avant et Après 2013', fontsize=16)
plt.xlabel('Année')
plt.ylabel('Score de Similarité')
plt.legend()

plt.show()

# %%
# ------------------------------------------------------
# GRAPHIQUE 2 : Réaction du Marché (|CAR|)
# ------------------------------------------------------
plt.figure(figsize=(14, 6))

# On trace la valeur absolue des CAR (ABS_CAR)
sns.lineplot(x='date', y='ABS_CAR', data=df,
             label='Réaction Absolue du Marché (|CAR|)', color='green', alpha=0.6)

# Tendance lissée
df['car_ma_12'] = df['ABS_CAR'].rolling(window=12).mean()
sns.lineplot(x='date', y='car_ma_12', data=df,
             label='Tendance de la réaction', color='darkgreen', linewidth=2, linestyle='--')

plt.title('Évolution de la Réaction des Marchés aux annonces (Volatilité anormale)', fontsize=14)
plt.xlabel('Année')
plt.ylabel('Rendement Anormal Absolu (%)')
plt.legend()
plt.show()
